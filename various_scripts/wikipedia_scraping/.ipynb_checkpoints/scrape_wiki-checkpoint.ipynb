# %%
import wikipedia    
import pandas as pd
from collections import Counter

# %%
list_of_drug_lists = [#'DEA list of chemicals', 
                      'List of psychedelic drugs', 'List of opioids', 'List of androgens/anabolic steroids',
    'List of Schedule II drugs (US)', 'List of Schedule III drugs (US)', 'Drugs controlled by the UK Misuse of Drugs Act',
    'List of Schedule IV drugs (US)'
  #'List of androgens/anabolic steroids (alternate)', 
] #Go at least one step into the links

list_by_drug_types_noExt = ['GHB', 'Benzodiazepine']
list_by_drug_types_Ext = ['MDMA Drug', 'Phencyclidine', 'Ketamine', 'Hashish', 'List of names for cannabis strains', 
                          'Cannabis strain',
                            'Cannabis edible', 'Cannabis concentrate', 'Lysergic acid diethylamide', 'Mescaline',
                         'Psilocybin mushroom', 'N,N-Dimethyltryptamine', 'Methamphetamine', 'Cocaine']

#For V.02 TODO  maybe remove the DEA list of chemicals

# %%
#Get all wikipedia Pages I wanna scrape
all_links = list_by_drug_types_noExt
all_links.extend(list_by_drug_types_Ext)
ext_refs = []

for i in list_of_drug_lists:
    try:
        page = wikipedia.page(title=i)
        all_links.extend(page.links)
    except DisambiguationError as error:
        print('Disambiguation error at ', i, ' may refer to: ', error.may_refer_to)
print('Total of Wiki Links ', len(all_links) )
# Out:
# Total of Wiki Links  2143

# %%
#Add Articles which seem related to the topics

all_links.extend(wikipedia.search("Cannabis strains", results=100, suggestion=True)[0])
all_links.extend(wikipedia.search("Hashish", results=18, suggestion=True)[0])
all_links.extend(wikipedia.search("MDMA Drug", results=100, suggestion=True)[0])
all_links.extend(wikipedia.search("Cocaine", results=100, suggestion=True)[0])
all_links.extend(wikipedia.search("Steroids", results=100, suggestion=True)[0])
all_links.extend(wikipedia.search("Opiods", results=100, suggestion=True)[0])
all_links.extend(wikipedia.search("prescription drug abuse", results=100, suggestion=True)[0])
all_links.extend(wikipedia.search("Benzodiazepine", results=150, suggestion=True)[0])
all_links.extend(wikipedia.search("Amphetamine", results=100, suggestion=True)[0])
all_links.extend(wikipedia.search("LSD DMT", results=100, suggestion=True)[0])

print('Total of Wiki Links With Extended Search ', len(all_links) )
# Out:
# Total of Wiki Links With Extended Search  3011

# %%
#Get External Links --> maybe I can scrape them too later..
'''
for i in list_by_drug_types_Ext:
    try:
        page = wikipedia.page(title=i)
        ext_refs.extend(page.references)
    except DisambiguationError as error:
        print('Disambiguation error at ', i, ' may refer to: ', error.may_refer_to)
print('Total of external References ', len(ext_refs) )
'''
# Out:
# "\nfor i in list_by_drug_types_Ext:\n    try:\n        page = wikipedia.page(title=i)\n        ext_refs.extend(page.references)\n    except DisambiguationError as error:\n        print('Disambiguation error at ', i, ' may refer to: ', error.may_refer_to)\nprint('Total of external References ', len(ext_refs) )\n"

# %%
#Remove duplicates
unique_links = list(dict.fromkeys(all_links))
print('We are going to load the content of ', len(unique_links), ' Wiki pages')
# Out:
# We are going to load the content of  2801  Wiki pages

# %%
#Do the download
titles = []
contents = []
categories = []
for link in unique_links:
    try:
        page = wikipedia.page(title=link)
        contents.append(page.content.encode('ascii', 'ignore').decode())
        titles.append(page.title)#redudant in case a page is not found

        categories.extend(page.categories) # Only for stats..
    
    except Exception as e:
        print("ERROR ", e, " at: ", link)
    
    
text_corpus = pd.DataFrame()
text_corpus['title'] = titles
text_corpus['text'] = contents
# Out:
# ERROR  Page id "1 butyl 3 2 methoxybenzoyl indoor" does not match any pages. Try another id!  at:  1-Butyl-3-(2-methoxybenzoyl)indole
# ERROR  Page id "1p-ls" does not match any pages. Try another id!  at:  1P-LSD
# ERROR  Page id "1b-lsd" does not match any pages. Try another id!  at:  1cP-LSD
# ERROR  Page id "2-me-dot" does not match any pages. Try another id!  at:  2-Me-DET
# ERROR  Page id "2c c" does not match any pages. Try another id!  at:  2C-B
# ERROR  Page id "2c e" does not match any pages. Try another id!  at:  2C-P
# ERROR  Page id "4-aco-det" does not match any pages. Try another id!  at:  4-AcO-DALT
# ERROR  Page id "4-aco-dmt" does not match any pages. Try another id!  at:  4-AcO-DET
# ERROR  Page id "4-aco-det" does not match any pages. Try another id!  at:  4-AcO-DPT
# ERROR  Page id "4-aco-dpt" does not match any pages. Try another id!  at:  4-AcO-EiPT
# ERROR  Page id "4 ho malt" does not match any pages. Try another id!  at:  4-AcO-MALT
# /home/bogenspergerj/anaconda3/envs/NER36/lib/python3.6/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /home/bogenspergerj/anaconda3/envs/NER36/lib/python3.6/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# ERROR  "4D" may refer to:
# spacetime
# Four-dimensional space
# 4D printing
# SGI IRIS 4D
# Selective Service System
# 4-D (psychedelic)
# 4D BIM
# Cinema 4D
# 4D (train)
# 4-Digits
# Air Sinai
# 4D (software)
# 4D SAS
# 4D Inc
# photo print size
# Ring finger
# 4D Audio Recording system
# Potez 4D
# 4DX
# 4D film
# 4DTV
# "4-D" (The X-Files)
# Metal Fight Beyblade 4D
# 4D (album)
# Aftermathematics
# Revenge of the Cybermen
# D4 (disambiguation)
# Fourth dimension (disambiguation)  at:  4-D (psychedelic)
# ERROR  Page id "4 ho dale" does not match any pages. Try another id!  at:  4-HO-DALT
# ERROR  Page id "4 ho mall" does not match any pages. Try another id!  at:  4-HO-MALT
# ERROR  Page id "5 meo dmt" does not match any pages. Try another id!  at:  5-MeO-DPT
# ERROR  Page id "5-meo-met" does not match any pages. Try another id!  at:  5-MeO-EPT
# ERROR  Page id "5 meo pipe" does not match any pages. Try another id!  at:  5-MeO-PiPT
# ERROR  Page id "5f py pineda" does not match any pages. Try another id!  at:  5F-PY-PINACA
# ERROR  Page id "9-nor-9ß-Hydroxyhexahydrocannabinol" does not match any pages. Try another id!  at:  9-nor-9ß-Hydroxyhexahydrocannabinol
# ERROR  Page id "a 423579" does not match any pages. Try another id!  at:  A-42574
# ERROR  Page id "ab 1" does not match any pages. Try another id!  at:  AB-001
# ERROR  Page id "ab fubica 2 fluorobenzyl iso ir" does not match any pages. Try another id!  at:  AB-FUBINACA 2-fluorobenzyl isomer
# ERROR  Page id "am 12" does not match any pages. Try another id!  at:  AM-1220
# ERROR  Page id "am 1340" does not match any pages. Try another id!  at:  AM-1346
# ERROR  Page id "am 1380" does not match any pages. Try another id!  at:  AM-1387
# ERROR  Page id "am 4" does not match any pages. Try another id!  at:  AM-411
# ERROR  Page id "am 411" does not match any pages. Try another id!  at:  AM-4113
# ERROR  Page id "am 652" does not match any pages. Try another id!  at:  AM-6527
# ERROR  Page id "am 95" does not match any pages. Try another id!  at:  AM-919
# ERROR  Page id "am-365" does not match any pages. Try another id!  at:  AMG-36
# ERROR  Page id "am-41" does not match any pages. Try another id!  at:  AMG-41
# ERROR  Page id "cay 104th" does not match any pages. Try another id!  at:  CAY-10429
# ERROR  Page id "cay 10000" does not match any pages. Try another id!  at:  CAY-10508
# ERROR  "CB25" may refer to:
# CB-25
# CB postcode area  at:  CB-25
# ERROR  Page id "curly bicaz" does not match any pages. Try another id!  at:  CUMYL-BICA
# ERROR  "Counter Culture" may refer to:
# Counterculture
# Counterculture of the 1960s
# Counter Culture (album)
# Counter Culture (EP)
# Counter Culture (TV pilot)  at:  Counterculture
# ERROR  "DMM" may refer to:
# Disease Models & Mechanisms
# Domestic Mail Manual
# Digital multimeter
# Digital Molecular Matter
# Direct metal mastering
# Daniel Martin Moore
# DMM Corporation
# DMM.com
# Dynamic-Maturational Model of Attachment and Adaptation
# King Fahd International Airport
# Project DMM  at:  DMMDA
# ERROR  Page id "doal" does not match any pages. Try another id!  at:  DOAM
# ERROR  "DOF" may refer to:
# Depth of field
# Depth of focus
# Digital obstacle file
# 2,5-Dimethoxy-4-fluoroamphetamine
# Distance-of-Flight
# Degrees of freedom
# Deeds of Flesh
# Deutsch-Österreichisches Feingefühl
# Dansk Ornitologisk Forening
# Department of Finance (Philippines)
# Department of Finance (Northern Ireland)
# Diario Oficial de la Federación
# DOF ASA
# DOF Subsea
# Documento de Origem Florestal  at:  DOEF
# ERROR  "DOC" may refer to:
# Doc (2001 TV series)
# Doc (1975 TV series)
# "D.O.C." (Lost)
# Doc (film)
# Doc (nickname)
# Doctor
# The D.O.C.
# Drew Hankinson
# David O. Calder
# David O. Carpenter
# David O. Carter
# David Oliver Cauldwell
# Dennis O. Cawthorne
# D. O. Chaoke
# David O. Conover
# David O. Cooke
# David Orgon Coolidge
# Daniel Ouezzin Coulibaly
# Dóc
# Livezile, Timiș
# Doc (Buffyverse)
# Doc (Chrono Cross)
# Doc (G.I. Joe)
# Doc (cartoon character)
# Doc Adams (Gunsmoke)
# Doc Boy
# Emmett Brown
# Doc Daneeka
# Doc Hudson
# Doc Louis
# Doc McStuffins
# Monte 'Doc' Parker
# The Secret Saturdays
# Doc Savage
# Fraggle Rock
# Elmer Andrews Bushnell
# Medical Officer Frank "Doc" DuFresne
# Snow White and the Seven Dwarfs
# United States Department of Commerce
# Department of Conservation (New Zealand)
# Department of Corrections
# Doc (computing)
# DiskOnChip
# Dave's own version of Citadel
# Department of Computing, Imperial College London
# Denominazione di origine controllata
# Denominação de Origem Controlada
# Denominación de Origen Calificada
# 11-Deoxycorticosterone
# 2,5-Dimethoxy-4-chloroamphetamine
# Deoxycholic acid
# Dartmouth Outing Club
# Documentary Organization of Canada
# Doc Films
# Day-old cockerel
# Diesel Oxidation Catalyst
# Dissolved organic carbon
# Doc (aircraft)
# Doc (mascot)
# North Dong
# Zucchero Fornaciari
# Dock (disambiguation)
# Docs (disambiguation)
# Doctor (disambiguation)
# Documentation  at:  DOx
# ERROR  "meda" may refer to:
# Tábua Municipality
# Gondomar Municipality, Portugal
# Meda-Ela
# Međa (Leskovac)
# Meda, Lombardy
# Mêda Municipality
# Meda, Oregon
# Meda River
# Meda, Togo
# Međa (Žitište)
# Alberto Meda
# Bianca Maria Meda
# Giuseppe Meda
# Igor Meda
# Jack Meda
# Meda of Odessos
# Meda Chesney-Lind
# Meda McKenzie
# Meda Mládková
# Meda Ryan
# A. C. Meda 1913
# HMS Meda
# MEDA
# Meda AB
# Meda (fish)
# Meda (mythology)
# SC Mêda  at:  EDMA
# ERROR  Page id "eids" does not match any pages. Try another id!  at:  EIDA
# ERROR  Page id "hu 3f8" does not match any pages. Try another id!  at:  HU-308
# ERROR  Page id "jwh 018" does not match any pages. Try another id!  at:  JWH-015
# ERROR  Page id "jwh-073" does not match any pages. Try another id!  at:  JWH-030
# ERROR  Page id "jwh-018" does not match any pages. Try another id!  at:  JWH-051
# ERROR  Page id "jwh13" does not match any pages. Try another id!  at:  JWH-133
# ERROR  Page id "mdat" does not match any pages. Try another id!  at:  MDBZ
# ERROR  "MDA" may refer to:
# Moldova
# A. P. Mda
# Zakes Mda
# Collections Trust
# Everytown for Gun Safety
# MacDonald, Dettwiler and Associates
# Magen David Adom
# Malaysia Design Archive
# Manicaland Development Association
# Maritime domain awareness
# Maxar Technologies
# MDA (company)
# Media Development Authority
# Medicines and Healthcare products Regulatory Agency
# Minnesota Department of Agriculture
# Missile Defense Agency
# Movement for Democracy in Africa
# Muscular Dystrophy Association
# Myanmar Dental Association
# Mail delivery agent
# computer-aided design
# event-driven architecture
# Mobile document access
# Model-driven architecture
# Microconnect distributed antenna
# IBM Monochrome Display Adapter
# Mobile digital assistant
# MDA framework
# methods, data, analyses
# Monthly Dragon Age
# within the human body
# Mean directional accuracy
# maternal antibodies naturally acquired
# MDA5
# Mass drug administration
# 2,3-Methylenedioxyamphetamine
# 3,4-Methylenedioxyamphetamine
# Misuse of Drugs Act 1971
# Misuse of Drugs Act (Ireland)
# Multiple displacement amplification
# 4,4'-Methylenedianiline
# Malondialdehyde
# daltons
# Metal deactivator
# MDA (TV series)
# Management discussion and analysis
# mesocyclone
# Multiple discriminant analysis
# IBM Monochrome Display Adapter
# instrument approach
# MDAS  at:  MDMA
# ERROR  Page id "mdos" does not match any pages. Try another id!  at:  MDOH
# ERROR  "MDR" may refer to:
# MDR1
# Diving reflex
# Medical device reporting
# Multiple drug resistance
# Managed security service
# Massive Data Repository
# Sony MDR-V6
# Medical device reprocessing
# Memory data register
# dead reckoning
# Merchant discount rate
# Metadata registry
# Metadata repository
# Mini D ribbon
# Motion detection
# Multifactor dimensionality reduction
# Desert Tech MDR
# Mandar language
# M. D. Ramanathan
# removing the classification of a document
# Medical Device Regulation
# Mitteldeutscher Rundfunk
# French expression
# Republican Democratic Movement
# All pages with titles beginning with MDR
# All pages with titles containing MDR
# MD (disambiguation)
# MDRA (disambiguation)
# MRD (disambiguation)  at:  MDPR
# ERROR  "Mem (disambiguation)" may refer to:
# Mem Castle
# Memphis International Airport
# Mem (given name)
# Master of Engineering Management
# Master of Environmental Management
# Missouri Employers Mutual
# Mondpaca Esperantista Movado
# The Main Event Mafia
# Memphis Grizzlies
# MEM (psychedelic)
# Chloroalkyl ether
# Mars Excursion Module
# Maximum entropy method
# Melted Extrusion Manufacturing
# Minimum Essential Medium
# Monocular estimate method
# Mem (computing)
# All pages with titles beginning with Mem
# All pages with titles containing mem
# Meme
# Mems (disambiguation)
# Memory (disambiguation)  at:  MEM (psychedelic)
# ERROR  Page id "m-15a" does not match any pages. Try another id!  at:  MJ-15
# ERROR  Page id "amai" does not match any pages. Try another id!  at:  MMAI
# ERROR  Page id "mam 2201" does not match any pages. Try another id!  at:  MMB-2201
# ERROR  Page id "nina 4100" does not match any pages. Try another id!  at:  NIDA-41020
# ERROR  Page id "but meg" does not match any pages. Try another id!  at:  Nutmeg
# ERROR  Page id "o 1101" does not match any pages. Try another id!  at:  O-1191
# ERROR  Page id "o 2008" does not match any pages. Try another id!  at:  O-2048
# ERROR  Page id "o 2013" does not match any pages. Try another id!  at:  O-2093
# ERROR  Page id "o 220" does not match any pages. Try another id!  at:  O-2220
# ERROR  Page id "o 235" does not match any pages. Try another id!  at:  O-2365
# ERROR  Page id "o 2371" does not match any pages. Try another id!  at:  O-2373
# ERROR  Page id "o 2387" does not match any pages. Try another id!  at:  O-2383
# ERROR  Page id "o 246" does not match any pages. Try another id!  at:  O-2426
# ERROR  Page id "o 2482" does not match any pages. Try another id!  at:  O-2484
# ERROR  Page id "o 2694" does not match any pages. Try another id!  at:  O-2654
# ERROR  Page id "o 2716" does not match any pages. Try another id!  at:  O-2715
# ERROR  Page id "o 322" does not match any pages. Try another id!  at:  O-3223
# ERROR  Page id "o 322" does not match any pages. Try another id!  at:  O-3226
# ERROR  Page id "org 2977" does not match any pages. Try another id!  at:  Org 29647
# ERROR  Page id "pre drug" does not match any pages. Try another id!  at:  Prodrug
# ERROR  "quick" may refer to:
# Quick, Nebraska
# Quick, West Virginia
# Quick (restaurant)
# Quick (sportswear)
# Quick (automobile)
# QIC (data backup)
# The Quick (U.S. band)
# The Quick (UK band)
# Quick (dance group)
# Quick (album)
# Quick (1932 film)
# Teri Polo
# Quick (2011 film)
# Quick (German magazine)
# Quick (newspaper)
# AHC Quick
# Quick 1888
# fast bowler
# Quick (surname)
# James Murphy (gridiron football)
# James "Quick" Parker
# James Tillis
# hyponychium
# USS Quick (DD-490)
# QUICK scheme
# railway crew management in India
# Quickening (disambiguation)
# Quik  at:  QUPIC
# ERROR  Page id "trip pop" does not match any pages. Try another id!  at:  Trip hop
# ERROR  Page id "d ser2 leaf that enkephalin" does not match any pages. Try another id!  at:  (D-Ser2, Leu5, Thr6)-Enkephalin
# ERROR  Page id "1 chlorocodide" does not match any pages. Try another id!  at:  1-Chlorocodeine
# ERROR  Page id "14 hydroxymorphinan" does not match any pages. Try another id!  at:  14-Hydroxymorphine
# ERROR  Page id "5,9 alpha dimethyl 2 hydroxybenzomorphan" does not match any pages. Try another id!  at:  5,9 alpha-diethyl-2-hydroxybenzomorphan
# ERROR  Page id "7-Benzylidenenaltrexone" does not match any pages. Try another id!  at:  7-Benzylidenenaltrexone
# ERROR  Page id "adl 57th" does not match any pages. Try another id!  at:  ADL-5747
# ERROR  Page id "adl 585" does not match any pages. Try another id!  at:  ADL-5859
# ERROR  Page id "az mta" does not match any pages. Try another id!  at:  AZ-MTAB
# ERROR  Page id "azd 237" does not match any pages. Try another id!  at:  AZD-2327
# ERROR  Page id "alpha gliding" does not match any pages. Try another id!  at:  Alpha-Gliadin
# ERROR  Page id "alpha narcotics" does not match any pages. Try another id!  at:  Alpha-Narcotine
# ERROR  Page id "bl 240" does not match any pages. Try another id!  at:  BL-2401
# ERROR  Page id "bms 986231" does not match any pages. Try another id!  at:  BMS-986121
# ERROR  Page id "bovine adrenal medulla peptide 12p" does not match any pages. Try another id!  at:  Bovine adrenal medullary peptide-12P
# ERROR  Page id "bovine adrenal medulla peptide 18p" does not match any pages. Try another id!  at:  Bovine adrenal medullary peptide-18P
# ERROR  Page id "boeing adrenal medulla peptide 22p" does not match any pages. Try another id!  at:  Bovine adrenal medullary peptide-22P
# ERROR  "CTO" may refer to:
# Chief technology officer
# Chief Technology Officer of the United States
# Certified Television Operator
# Cape Town Opera
# Caribbean Tourism Organization
# Central Treaty Organization
# Commonwealth Telecommunications Organisation
# Cyprus Tourism Organisation
# CTO Hospital (Turin)
# Cancelled-to-order
# Chronic total occlusion
# City ticket office
# color correction
# Community treatment order  at:  CTOP
# ERROR  Page id "cym 51001" does not match any pages. Try another id!  at:  CYM-51010
# ERROR  "coding" may refer to:
# Computer programming
# Line coding
# Source coding
# Coding theory
# Channel coding
# Coding (social sciences)
# Coding strand
# Legal coding
# Medical coding
# Code
# Entropy encoding
# Transform coding  at:  Codide
# ERROR  "diana" may refer to:
# Diana (name)
# Diana (mythology)
# Diana, Princess of Wales
# Diana (see)
# Diana's Peak
# Diana Region
# Diana Veteranorum
# Diana, New York
# Diana, Saskatchewan
# Diana, Iraq
# Diana (Rozvadov)
# Diana, Silesian Voivodeship
# Diana Fortress
# Diana Strait
# Golubac
# 78 Diana
# Diana (crater)
# Diana (pastoral romance)
# Diana (Sailor Moon)
# Wonder Woman
# DC Thomson
# Diana (film)
# 4 Hearts
# Diana (Lights Out)
# Diana (U.S. TV series)
# Diana (UK TV series)
# "Diana" (Spooks)
# Diana (musical)
# Diana (band)
# Diana!
# Diana (album)
# "Diana" (Paul Anka song)
# First Utterance
# Tempest in the Colosseum
# "Diana" (Bryan Adams song)
# "Diana" (One Direction song)
# The Roots of My Raising
# Diana (ship)
# Diana (1824 ship)
# Diana (1840 ship)
# Russian cruiser Diana
# Russian frigate Diana
# Diana (Felderhoff)
# Diana (Wiken)
# Diana (Saint-Gaudens)
# Diana of Versailles
# Democratic Renewal
# divisive clustering
# DIANA FEA
# DIANA (intermediate language)
# DIANA Mayer & Grammelspacher
# Diana (agricultural machinery)
# Diana (camera)
# Diana (swimwear)
# Diana (Vouet)
# Diana (Renoir painting)
# Diana (locomotive)
# Diane (disambiguation)
# Diana Department Store
# Diana monkey
# Diana Motors Company
# All pages with titles beginning with Diana  at:  DIPPA
# ERROR  Page id "pdp" does not match any pages. Try another id!  at:  DPDPE
# ERROR  Page id "functional selecticity" does not match any pages. Try another id!  at:  Functional selectivity
# ERROR  "IC 26" may refer to:
# IC-26
# NGC 135  at:  IC-26
# ERROR  Page id "ici 1542" does not match any pages. Try another id!  at:  ICI-154129
# ERROR  Page id "ici 1764" does not match any pages. Try another id!  at:  ICI-174864
# ERROR  Page id "ms 350" does not match any pages. Try another id!  at:  ML350
# ERROR  Page id "mr 2014" does not match any pages. Try another id!  at:  MR-2034
# ERROR  Page id "mr 226" does not match any pages. Try another id!  at:  MR-2266
# ERROR  Page id "mt 771" does not match any pages. Try another id!  at:  MT-7716
# ERROR  Page id "morphol" does not match any pages. Try another id!  at:  Morphenol
# ERROR  Page id "n mpp" does not match any pages. Try another id!  at:  N-MPPP
# ERROR  Page id "Oxymorphone p-nitrophenylhydrazone" does not match any pages. Try another id!  at:  Oxymorphone p-nitrophenylhydrazone
# ERROR  "PPAP" may refer to:
# Production part approval process
# (-)-1-Phenyl-2-propylaminopentane
# PPAP (Pen-Pineapple-Apple-Pen)
# PEPAP  at:  PEPAP
# ERROR  Page id "ram 37" does not match any pages. Try another id!  at:  RAM-378
# ERROR  Page id "rb-50" does not match any pages. Try another id!  at:  RB-101
# ERROR  Page id "road 650" does not match any pages. Try another id!  at:  Ro65-6570
# ERROR  Page id "sb 2386" does not match any pages. Try another id!  at:  SB-235863
# ERROR  Page id "sch 22100" does not match any pages. Try another id!  at:  SCH-221510
# ERROR  Page id "sr 1630" does not match any pages. Try another id!  at:  SR-16430
# ERROR  Page id "sr 1645" does not match any pages. Try another id!  at:  SR-16435
# ERROR  Page id "sr 899" does not match any pages. Try another id!  at:  SR-8993
# ERROR  Page id "up in" does not match any pages. Try another id!  at:  UPHIT
# ERROR  Page id "Αlpha-chlorocodide" does not match any pages. Try another id!  at:  Αlpha-chlorocodide
# ERROR  Page id "ac 262,536" does not match any pages. Try another id!  at:  AC-262536
# ERROR  Page id "azd 351" does not match any pages. Try another id!  at:  AZD-3514
# ERROR  Page id "antartida" does not match any pages. Try another id!  at:  Antarlide
# ERROR  Page id "bms 564,929" does not match any pages. Try another id!  at:  BMS-564929
# ERROR  Page id "bms 57001" does not match any pages. Try another id!  at:  BMS-570511
# ERROR  Page id "bisphenol c" does not match any pages. Try another id!  at:  Bisphenol F
# ERROR  Page id "dtdp" does not match any pages. Try another id!  at:  DTIB
# ERROR  Page id "em 435" does not match any pages. Try another id!  at:  EM-4350
# ERROR  Page id "em 5854" does not match any pages. Try another id!  at:  EM-5855
# ERROR  Page id "em 653" does not match any pages. Try another id!  at:  EM-6537
# ERROR  Page id "em 901" does not match any pages. Try another id!  at:  EM-9017
# ERROR  Page id "ftse 1" does not match any pages. Try another id!  at:  FTBU-1
# ERROR  Page id "gsk 869" does not match any pages. Try another id!  at:  GSK-8698
# ERROR  Page id "once 13b" does not match any pages. Try another id!  at:  ONC1-13B
# ERROR  Page id "orm 1184" does not match any pages. Try another id!  at:  ORM-11984
# ERROR  Page id "pf 99942" does not match any pages. Try another id!  at:  PF-998425
# ERROR  Page id "ru 153rd" does not match any pages. Try another id!  at:  RU-15328
# ERROR  Page id "s 10047" does not match any pages. Try another id!  at:  S-101479
# ERROR  Page id "s-405" does not match any pages. Try another id!  at:  S-40503
# ERROR  Page id "ym 1775" does not match any pages. Try another id!  at:  YM-175735
# ERROR  Page id "ym 92001" does not match any pages. Try another id!  at:  YM-92088
# ERROR  "Cannabis (disambiguation)" may refer to:
# Carduelis
# Cannabis
# C. indica
# C. ruderalis
# C. sativa
# Hashish or hash
# Cannabis strains
# Feral cannabis
# Cannabis consumption
# 420 (cannabis culture)
# Cannabis dependence
# Cannabis smoking
# Effects of cannabis
# Cannabis (drug)
# Synthetic cannabis
# Cannabis flower essential oil
# Cannabis foods
# Cannabis tea
# Maltos-Cannabis
# Tincture of cannabis
# Entheogenic use of cannabis
# Cannabis and religion
# Medical cannabis
# Cannabis Culture (magazine)
# Cannabis Cup
# Cannabis (film)
# Cannabis (film score)
# Cannabis Museum (Japan)
# Cannabis Planet
# High Times Medical Cannabis Cup
# Kid Cannabis
# Montevideo Cannabis Museum
# Whakamana Cannabis Museum
# Alliance for Cannabis Therapeutics
# American Alliance for Medical Cannabis
# Aotearoa Legalise Cannabis Party
# Buffalo Cannabis Movement
# California Cannabis Research Medical Group
# Cannabis City
# Cannabis Farmers Market
# Cannabis Law Reform
# Cannabis Party (Denmark)
# Cannabis Party (Spain)
# Coalition for Rescheduling Cannabis
# First Church of Cannabis
# Grassroots-Legalize Cannabis Party
# Massachusetts Cannabis Reform Coalition
# National Cannabis Industry Association
# Society of Cannabis Clinicians
# Veterans for Medical Cannabis Access
# Cannabis culture
# Cannabis refugee
# Cannabis rights
# Cannabis shop
# Cannabis City
# Cannabis (word)
# Adult lifetime cannabis use by country
# Annual cannabis use by country
# Cannabis dispensaries in the United States
# Cannabis political parties
# Dagga (disambiguation)
# Etymology of cannabis
# Ganja (disambiguation)
# Glossary of cannabis terms
# Hemp (disambiguation)
# Legality of cannabis by country
# List of anti-cannabis organizations
# List of cannabis companies
# List of cannabis competitions
# List of cannabis rights leaders
# List of cannabis rights organizations
# List of cannabis seizures
# List of names for cannabis
# List of names for cannabis strains
# Marijuana (disambiguation)  at:  Cannabis (disambiguation)
# ERROR  "Haze (disambiguation)" may refer to:
# Haze
# Haze machine
# Turbidity
# Haze (optics)
# Corneal opacification
# Hazing
# Haze (2005 film)
# Haze (2010 film)
# Haze (video game)
# Haze (band)
# "Haze" (song)
# Lolita
# Eric Haze
# Jenna Haze
# Jonathan Haze
# John Haze
# Angel Haze
# Harikrish Menon
# Haze
# Mil Mi-14
# Purple Haze (disambiguation)  at:  Haze (disambiguation)
# ERROR  "daga" may refer to:
# Daga (wrestler)
# Dagmara Wozniak
# Daga District, Bhutan
# Daga, Bhutan
# Daga Hundred
# Daga Island
# Daga River (disambiguation)
# Daga Rural LLG
# Daga language  at:  Dagga
# ERROR  "Kush" may refer to:
# Cush (Bible)
# Kush (mountain)
# Kush (satrapy)
# Hindu Kush
# Kingdom of Kush
# Cush (hill)
# Kush Arora
# Cush Jumbo
# Kusha (Ramayana)
# Lennox Cush
# Wilbur Cush
# Emil Kush
# Eric Kush
# Frank Kush
# Kundan Singh Kush
# Rod Kush
# Vladimir Kush
# Cush (band)
# Kush (band)
# Kush (group)
# "Kush" (song)
# The Kush
# Kush (Conan)
# Kush (film)
# "Kush" (Sanctuary)
# KUSH
# Kush Games
# Kush (Cannabis)
# Kusha grass
# Kush (maize)
# Kush Housing Association
# Cushitic languages
# Hindukush (disambiguation)
# Koosh ball
# Kusha (disambiguation)
# Kushan Empire
# Kushi (disambiguation)
# Qush (disambiguation)
# All pages with titles containing kush  at:  Kush
# ERROR  Page id "charlotte fiji" does not match any pages. Try another id!  at:  Charlotte Figi
# ERROR  "Mary Jane" may refer to:
# Mary J. Blige
# Mary Jane Clark
# Mary Jane Croft
# Mary Jane Irving
# Mary Jane Kelly
# Mary Jane Lamond
# Mary Jane Osborn
# Mary Jane Owen
# Mary Jane Peale
# Mary Jane Phillips-Matz
# Mary J. Rathbun
# Brownie Mary
# Mary Jane Reoch
# Mary Jane and Sniffles
# Mary Jane Watson
# Mary Jane (All Night Long)
# "Mary Jane" (Janis Joplin song)
# "Mary Jane" (Megadeth song)
# "Mary Jane" (Rick James song)
# "Mary Jane" (Scarface song)
# The Miracle Workers
# Luke Tan
# Jagged Little Pill
# Devolution
# EPdemic
# Modern Minds and Pastimes
# Happy Birthday
# Turn It Upside Down
# Headsex
# Highly Evolved
# Omo Baba Olowo
# Abnormally Attracted to Sin
# Goodlyfe Crew
# Ars Moriendi
# Mic Christopher
# Seventh Heaven
# Mary + Jane
# Maryjane (film)
# Mary Jane (candy)
# Mary Jane (shoe)
# Mary Jane (slang)
# Winter Park Resort
# All pages with titles beginning with Mary Jane  at:  Merry Jane
# ERROR  "Skunk (disambiguation)" may refer to:
# Skunk Creek (Gooseberry River)
# Skunk Creek (Peruque Creek)
# Skunk Creek (South Dakota)
# Skunk River (Platte River)
# Skunk River
# Jeff Baxter
# Skunk (band)
# Skunk Anansie
# Skunk Records
# KUNK
# Skunk.nu
# Skunk 11
# Skunk (Cannabis strain)
# Skunk (weapon)
# Mercy rule
# California Western Railroad
# SCO Skunkware
# Skunked beer
# Skunkworks (disambiguation)  at:  Skunk (disambiguation)
# ERROR  "Sour (disambiguation)" may refer to:
# Sour
# Sour (cocktail)
# Souring
# Sour (album)
# "Sour" (song)
# Sour, Algeria
# Tyre, Lebanon
# Sun of Unclouded Righteousness
# Sours
# SUR (disambiguation)
# Tart (disambiguation)  at:  Sour (disambiguation)
# ERROR  "Substance" may refer to:
# Substance (Jainism)
# Chemical substance
# Matter
# Substance theory
# Ousia
# Drug
# Substance abuse
# Substance dependence
# Substance (Blank & Jones album)
# Substance (Joy Division album)
# Substance 1987
# That They May Know You
# SubStance
# Metal Gear Solid 2: Sons of Liberty
# Dravya
# Homoousion
# Homoiousian
# Substance control (disambiguation)
# Substantial (rapper)  at:  Substance abuse
# ERROR  "Ecstasy" may refer to:
# Ecstasy (emotion)
# Religious ecstasy
# Ecstasy (philosophy)
# Ecstasy (drug)
# Ecstasy: Three Tales of Chemical Romance
# Ecstasies (book)
# Ecstasy (comics)
# John Donne
# XTC
# Ecstasy (Avant album)
# Ecstasy (Deuter album)
# Ecstasy (Kissin' Dynamite album)
# Ecstasy (Lou Reed album)
# Ecstasy (My Bloody Valentine album)
# Ecstasy (Ohio Players album)
# Ecstasy (Steve Kuhn album)
# "Ecstasy" (ATB song)
# "Ecstasy" (Jody Watley song)
# "Ecstasy" (Koda Kumi song)
# "Ecstasy" (New Order song)
# BTNHResurrection
# Shaken by a Low Sound
# Dance Dance Revolution Extreme
# Are You Listening?
# Welcome to the Dollhouse
# Darkness Darkness
# You're Nothing
# jj n° 2
# Risk
# The Stripes
# zZz
# Doc Pomus
# Ecstasy (film)
# Ecstasy (play)
# Ecstasy (Gill sculpture)
# Irvine Welsh's Ecstasy
# Carnival Ecstasy
# Ecstasy (clothing)
# "Extacy" (Kanye West song)
# Extasy Records
# XTC (disambiguation)
# Ekstasis (disambiguation)  at:  Ecstasy
# ERROR  Page id "mdma drug" does not match any pages. Try another id!  at:  MMDA (drug)
# ERROR  "Cocaine (disambiguation)" may refer to:
# Cocaine (data page)
# Cocaine (film)
# The Pace That Kills (1935 film)
# Cocaine: An Unauthorized Biography
# Cocaine Blues (novel)
# Cocaine (album)
# Cocaine" (song)
# Seventh Heaven
# On Down the Road
# Cocaine Blues
# Cocaine (PaaS)
# Cocaine (drink)
# Honey Cocaine
# List of cocaine analogues
# Kokane
# Cockayne (disambiguation)
# All pages with titles containing Cockaigne  at:  Cocaine (disambiguation)
# ERROR  Page id "cocaine blue" does not match any pages. Try another id!  at:  Cocaine Blues
# ERROR  Page id "kate miss" does not match any pages. Try another id!  at:  Kate Moss
# ERROR  "Cocaine Cowboys (disambiguation)" may refer to:
# Cocaine Cowboys (1979 film)
# Helldorado
# The Savage Playground
# All American Made  at:  Cocaine Cowboys (disambiguation)
# ERROR  "Cocaine Coup" may refer to:
# 1980 Bolivian coup d'état
# 1978 Honduran coup d'état  at:  Cocaine Coup
# ERROR  Page id "mickey monday" does not match any pages. Try another id!  at:  Mickey Munday
# ERROR  Page id "scott stitch" does not match any pages. Try another id!  at:  Scott Storch
# ERROR  Page id "gary west" does not match any pages. Try another id!  at:  Gary Webb
# ERROR  Page id "rich diana" does not match any pages. Try another id!  at:  Rich Piana
# ERROR  Page id "mark mcguire" does not match any pages. Try another id!  at:  Mark McGwire
# ERROR  Page id "jeremy gianni" does not match any pages. Try another id!  at:  Jeremy Giambi
# ERROR  Page id "corey hair" does not match any pages. Try another id!  at:  Corey Haim
# ERROR  Page id "mike kelly wrestler" does not match any pages. Try another id!  at:  Mike Bell (wrestler)
# ERROR  Page id "health ledger" does not match any pages. Try another id!  at:  Heath Ledger
# ERROR  Page id "jeff conway" does not match any pages. Try another id!  at:  Jeff Conaway
# ERROR  Page id "poper" does not match any pages. Try another id!  at:  Poppers
# ERROR  Page id "the job 2013 tv series" does not match any pages. Try another id!  at:  The Job (2001 TV series)
# ERROR  "Chlorodiazepam" may refer to:
# Diclazepam
# Ro5-4864  at:  Chlorodiazepam
# ERROR  Page id "scutellaris" does not match any pages. Try another id!  at:  Scutellaria
# ERROR  Page id "jordan person" does not match any pages. Try another id!  at:  Jordan Peterson
# ERROR  "Tavor (disambiguation)" may refer to:
# IWI Tavor
# Camp Tavor
# Lorazepam
# Tabor (disambiguation)  at:  Tavor (disambiguation)
# ERROR  "Amphetamine (disambiguation)" may refer to:
# Substituted amphetamine
# Dextroamphetamine
# Levoamphetamine
# Adderall
# Lisdexamfetamine
# Amphetamine (film)
# Amphetamine Reptile Records
# So Much for the Afterglow
# History and culture of amphetamines  at:  Amphetamine (disambiguation)
# ERROR  Page id "the figs" does not match any pages. Try another id!  at:  The Fugs
# ERROR  Page id "mark jacobson" does not match any pages. Try another id!  at:  Max Jacobson
# ERROR  Page id "vietnam was" does not match any pages. Try another id!  at:  Vietnam War
# ERROR  "roman" may refer to:
# Rome
# Ancient Rome
# Roman people
# Epistle to the Romans
# Romans (band)
# Roman (album)
# Roman (EP)
# Roman (My Dear Boy)
# Film Roman
# Roman (film)
# Romans (2013 film)
# Romans (2017 film)
# The Romans (Doctor Who)
# Roman (given name)
# Roman (surname)
# name of the Greeks
# Italic peoples
# Roman, Bulgaria
# Roman Municipality
# Roman, Eure
# Roman, Romania
# Roman County
# Roman, Sakha Republic
# Roman River
# Roman Valley, Nova Scotia
# Romans, Ain
# Romans, Deux-Sèvres
# Romans d'Isonzo
# Romans-sur-Isère
# Roman Catholic
# Roman Catholic (term)
# Ar-Rum
# Rûm
# Nancy Grace Roman Space Telescope
# Roman (company)
# Roman (vehicle manufacturer)
# Roman script
# Roman type
# All pages with titles containing Roman
# All pages with titles containing Romans
# All pages with titles beginning with Roman
# All pages with titles beginning with Romans
# History of Rome (disambiguation)
# Roman language (disambiguation)
# Rome (disambiguation)
# Greco-Roman world
# Romani people  at:  Romania

# %%
text_corpus.tail(10)
text_corpus.shape
# Out:
# (2626, 2)

# %%
#Check the most common categories of my articles
cat_stats = Counter(categories)

# %%
sorted_cat_stats = {k: v for k, v in sorted(cat_stats.items(), key=lambda item: item[1], reverse=True)}
sorted_cat_stats
# Out:
# {'Articles without KEGG source': 1309,
#  'Chemical pages without DrugBank identifier': 1038,
#  'Articles containing unverified chemical infoboxes': 860,
#  'Articles without EBI source': 849,
#  'All stub articles': 813,
#  'Articles with short description': 663,
#  'ECHA InfoCard ID from Wikidata': 638,
#  'All articles with unsourced statements': 637,
#  'Drugs missing an ATC code': 622,
#  'Drugboxes which contain changes to watched fields': 522,
#  'Drugs with no legal status': 521,
#  'Drugboxes which contain changes to verified fields': 486,
#  'Articles without UNII source': 478,
#  'Drugs not assigned an ATC code': 436,
#  'Short description is different from Wikidata': 393,
#  'Articles with changed CASNo identifier': 346,
#  'Pages using collapsible list with both background and text-align in titlestyle': 346,
#  'Drugs with non-standard legal status': 342,
#  'Webarchive template wayback links': 316,
#  'Designer drugs': 316,
#  'All articles needing additional references': 289,
#  'Short description matches Wikidata': 267,
#  'Mu-opioid agonists': 258,
#  'CS1: long volume value': 245,
#  'Chembox image size set': 244,
#  'Androgens and anabolic steroids': 222,
#  'All articles with dead external links': 220,
#  'Articles with changed EBI identifier': 213,
#  'Analgesic stubs': 192,
#  'Articles with changed InChI identifier': 187,
#  'Articles with changed ChemSpider identifier': 184,
#  'Opioids': 182,
#  'Articles with permanently dead external links': 178,
#  'Synthetic opioids': 178,
#  'CS1 German-language sources (de)': 177,
#  'Phenols': 175,
#  'Cannabinoids': 172,
#  'Commons category link is on Wikidata': 166,
#  'Articles without InChI source': 162,
#  'Cannabinoid stubs': 149,
#  'Wikipedia articles with LCCN identifiers': 144,
#  'Morphinans': 144,
#  'Androstanes': 144,
#  'Wikipedia articles with GND identifiers': 142,
#  'CS1 errors: missing periodical': 141,
#  'Analgesics': 139,
#  'Euphoriants': 134,
#  'CS1 maint: archived copy as title': 133,
#  'Chemical articles without CAS registry number': 133,
#  'All articles containing potentially dated statements': 128,
#  'Ketones': 128,
#  'Wikipedia medicine articles ready to translate': 127,
#  'Piperidines': 127,
#  'Chloroarenes': 124,
#  'Genito-urinary system drug stubs': 123,
#  'Prodrugs': 120,
#  'Steroid stubs': 119,
#  'All articles lacking reliable references': 114,
#  'World Anti-Doping Agency prohibited substances': 113,
#  'CS1 maint: multiple names: authors list': 110,
#  'Wikipedia articles with NDL identifiers': 109,
#  'Abandoned drugs': 109,
#  'Substituted amphetamines': 108,
#  'CS1 Chinese-language sources (zh)': 106,
#  'Progestogens': 105,
#  'Semisynthetic opioids': 102,
#  'Serotonin receptor agonists': 100,
#  'Phenol ethers': 99,
#  'CS1 French-language sources (fr)': 98,
#  'Hepatotoxins': 97,
#  'GABAA receptor positive allosteric modulators': 95,
#  'CS1 Swedish-language sources (sv)': 93,
#  'Entheogens': 89,
#  'Tertiary alcohols': 89,
#  'Chemical pages without ChemSpiderID': 88,
#  'Estranes': 88,
#  'Kappa agonists': 84,
#  'Infobox drug articles with non-default infobox title': 83,
#  'Multiple chemicals in an infobox that need indexing': 78,
#  'Opioid antagonists': 76,
#  'Wikipedia articles with BNF identifiers': 74,
#  'Fluoroarenes': 73,
#  'Commons category link from Wikidata': 71,
#  'Psychoactive drug stubs': 70,
#  'Nonsteroidal antiandrogens': 70,
#  'Enones': 69,
#  'Psychedelic tryptamines': 68,
#  'Chem-molar-mass both hardcoded and calculated': 67,
#  'Chemical articles with multiple compound IDs': 67,
#  'World Health Organization essential medicines': 65,
#  'Acetate esters': 64,
#  'Chemical articles with multiple CAS registry numbers': 62,
#  'Multiple chemicals in Infobox drug': 62,
#  'Wikipedia articles with VIAF identifiers': 61,
#  'All articles with incomplete citations': 61,
#  'CS1 Japanese-language sources (ja)': 60,
#  'Entactogens and empathogens': 60,
#  'Nervous system drug stubs': 60,
#  'Opioid peptides': 60,
#  'CB1 receptor agonists': 59,
#  'Trifluoromethyl compounds': 59,
#  'All articles lacking in-text citations': 59,
#  'Ethers': 57,
#  'Articles with hCards': 56,
#  'Drug has EMA link': 55,
#  'Hormonal antineoplastic drugs': 54,
#  'Hallucinogen stubs': 53,
#  'Anilides': 53,
#  'Wikipedia articles with WORLDCATID identifiers': 53,
#  'Chemicals using indexlabels': 52,
#  'Drug-related lists': 52,
#  'Lactams': 52,
#  'NMDA receptor antagonists': 50,
#  'Articles with dead external links from January 2018': 49,
#  'Steroidal antiandrogens': 49,
#  'Drug culture': 48,
#  'Articles with hAudio microformats': 48,
#  'Articles requiring reliable medical sources': 48,
#  'Living people': 48,
#  'Propionamides': 48,
#  'Benzodiazepines': 47,
#  'CS1 maint: uses authors parameter': 47,
#  'CS1 Spanish-language sources (es)': 46,
#  'Benzodioxoles': 45,
#  'Stimulants': 45,
#  'Psychedelic phenethylamines': 45,
#  'All Wikipedia articles in need of updating': 45,
#  'Androgen esters': 45,
#  'General anesthetics': 44,
#  'CB2 receptor agonists': 44,
#  'JWH cannabinoids': 44,
#  'Naphthoylindoles': 43,
#  'Articles with changed DrugBank identifier': 43,
#  "Articles with 'species' microformats": 42,
#  'Kappa antagonists': 42,
#  'Dissociative drugs': 41,
#  'Human drug metabolites': 41,
#  'Articles with dead external links from May 2019': 41,
#  'Articles with dead external links from March 2020': 41,
#  'All articles with vague or ambiguous time': 40,
#  'Serotonin-norepinephrine-dopamine releasing agents': 40,
#  'Sigma agonists': 40,
#  'Dimethylamino compounds': 40,
#  'Wikipedia indefinitely move-protected pages': 40,
#  'Articles with multiple maintenance issues': 40,
#  'Organofluorides': 40,
#  'Nitriles': 40,
#  'Secondary alcohols': 40,
#  'Articles with incomplete citations from April 2015': 40,
#  'Antigonadotropins': 40,
#  'Wikipedia articles with NKC identifiers': 39,
#  'Pregnanes': 39,
#  'Articles lacking in-text citations from January 2012': 39,
#  'Carboxamides': 38,
#  '5-HT2A agonists': 37,
#  'All pages needing factual verification': 37,
#  'Amines': 37,
#  'Benzochromenes': 37,
#  'Wikipedia articles with ISNI identifiers': 37,
#  'Nicotinic antagonists': 36,
#  'Wikipedia articles with NARA identifiers': 35,
#  '2C (psychedelics)': 35,
#  'Cyclopropanes': 35,
#  'CS1 maint: others': 35,
#  'Sedatives': 34,
#  'Carboxylate esters': 34,
#  'Articles with unsourced statements from June 2020': 34,
#  'Hypnotics': 33,
#  'CS1: Julian–Gregorian uncertainty': 33,
#  'German inventions': 33,
#  'All Wikipedia articles written in American English': 33,
#  'Wikipedia indefinitely semi-protected pages': 33,
#  'Delta-opioid agonists': 33,
#  'Articles containing potentially dated statements from 2015': 32,
#  'Drugs with unknown mechanisms of action': 32,
#  'CS1 Czech-language sources (cs)': 32,
#  'All articles to be expanded': 32,
#  'Estrogens': 32,
#  'AC with 0 elements': 32,
#  'Synthetic estrogens': 32,
#  'Antidepressants': 31,
#  'All articles with specifically marked weasel-worded phrases': 31,
#  'Use dmy dates from January 2020': 31,
#  'All articles with failed verification': 31,
#  'Articles with changed FDA identifier': 31,
#  'Alkyne derivatives': 31,
#  'Articles using small message boxes': 31,
#  'Peripherally selective drugs': 31,
#  'Organochlorides': 31,
#  'Phenethylamines': 30,
#  'Tryptamines': 30,
#  'Allyl compounds': 30,
#  'Pyrrolidines': 30,
#  'Diketones': 30,
#  'TAAR1 agonists': 29,
#  'Cyclohexanols': 29,
#  'CS1 Italian-language sources (it)': 29,
#  'Benzamides': 29,
#  'All articles that may contain original research': 28,
#  'Good articles': 28,
#  'Wikipedia pages semi-protected against vandalism': 28,
#  'All accuracy disputes': 28,
#  'Bromoarenes': 28,
#  'Thioethers': 28,
#  'Indazolecarboxamides': 28,
#  'Appetite stimulants': 28,
#  'Medicinal plants': 28,
#  'Articles with unsourced statements from September 2020': 28,
#  'Janssen Pharmaceutica': 28,
#  'Drugs that are a combination of chemicals': 28,
#  'Glucocorticoids': 28,
#  'Muscarinic antagonists': 27,
#  'Withdrawn drugs': 27,
#  'Lysergamides': 27,
#  'Chembox having GHS data': 27,
#  'Pages with citations lacking titles': 27,
#  'Antitussives': 27,
#  'Belgian inventions': 27,
#  'Wikipedia articles with BNE identifiers': 26,
#  'Glycine receptor agonists': 26,
#  'CS1 Russian-language sources (ru)': 26,
#  'Psychedelic drugs': 26,
#  'Anxiolytics': 26,
#  'Propionate esters': 26,
#  'Articles with changed KEGG identifier': 26,
#  'Pyridines': 26,
#  'Spiro compounds': 26,
#  'CS1 Portuguese-language sources (pt)': 25,
#  'Chemical substances for emergency medicine': 25,
#  'Cannabis smoking': 25,
#  'Articles with unsourced statements from July 2015': 25,
#  'Primary alcohols': 25,
#  'Iodoarenes': 25,
#  '25-NB (psychedelics)': 25,
#  'Indoles': 25,
#  'CS1 maint: DOI inactive as of November 2020': 25,
#  'Neuropeptides': 25,
#  'Piperazines': 25,
#  'Protein pages needing a picture': 25,
#  'Sodium channel blockers': 24,
#  'Anorectics': 24,
#  'Articles with unsourced statements from February 2020': 24,
#  'Pages containing links to subscription-only content': 24,
#  'Articles containing potentially dated statements from 2018': 24,
#  'Antimineralocorticoids': 24,
#  'Glycine receptor antagonists': 23,
#  'CS1 Dutch-language sources (nl)': 23,
#  'Articles with unsourced statements from December 2017': 23,
#  'CB1 receptor antagonists': 23,
#  'Articles containing potentially dated statements from 2019': 23,
#  'Fentanyl': 23,
#  'Johnson & Johnson brands': 23,
#  'Hormonal contraception': 23,
#  'Cannabis culture': 22,
#  'Aromatase inhibitors': 22,
#  'Cannabis': 22,
#  'AM cannabinoids': 22,
#  'Biochemistry stubs': 22,
#  'Morpholines': 22,
#  'GABAA receptor negative allosteric modulators': 22,
#  'Alkene derivatives': 22,
#  'Articles containing Ancient Greek (to 1453)-language text': 22,
#  'All pages needing cleanup': 22,
#  'Progestogen esters': 22,
#  'Antineoplastic and immunomodulating drug stubs': 22,
#  'Articles containing potentially dated statements from 2017': 21,
#  'VMAT inhibitors': 21,
#  'Cannabis strains': 21,
#  'Articles with Spanish-language sources (es)': 21,
#  'Articles with unsourced statements from July 2019': 21,
#  'Norepinephrine-dopamine releasing agents': 21,
#  'Teratogens': 21,
#  'Pfizer brands': 21,
#  'Monoamine oxidase inhibitors': 21,
#  'Drug rehabilitation': 21,
#  'Sex hormones': 21,
#  'Benzomorphans': 21,
#  '5α-Reductase inhibitors': 21,
#  'Serotonin-norepinephrine-dopamine reuptake inhibitors': 20,
#  'Articles with unsourced statements from March 2017': 20,
#  'Articles with German-language sources (de)': 20,
#  'Serotonin releasing agents': 20,
#  'Pages with citations having bare URLs': 20,
#  'Indolecarboxamides': 20,
#  'Acetamides': 20,
#  'CS1 maint: extra text: authors list': 20,
#  'CS1 Hebrew-language sources (he)': 20,
#  'Lactones': 20,
#  'Ethyl esters': 20,
#  'Pregnane X receptor agonists': 20,
#  'Diols': 20,
#  'Prostate cancer': 20,
#  'Selective androgen receptor modulators': 20,
#  'Articles containing video clips': 19,
#  'Calcium channel blockers': 19,
#  'Articles with unsourced statements from December 2019': 19,
#  'CS1 maint: BOT: original-url status unknown': 19,
#  'All articles lacking sources': 19,
#  'Articles with unsourced statements from August 2014': 19,
#  'Articles with unsourced statements from April 2020': 19,
#  'Articles with Curlie links': 19,
#  'Thiophenes': 19,
#  '5-HT2C agonists': 18,
#  'D2-receptor agonists': 18,
#  'Cocaine': 18,
#  'Wikipedia articles with MusicBrainz identifiers': 18,
#  'Amphetamine': 18,
#  'Organic compound stubs': 18,
#  'Combination drugs': 18,
#  'Enantiopure drugs': 18,
#  'Articles with unsourced statements from October 2015': 18,
#  'Endocrine disruptors': 18,
#  'Methamphetamines': 17,
#  'Use dmy dates from February 2020': 17,
#  'Articles with unsourced statements from January 2019': 17,
#  'Methyl esters': 17,
#  'CS1 Turkish-language sources (tr)': 17,
#  'Pyrazoles': 17,
#  'Wikipedia articles with NTA identifiers': 17,
#  'Articles containing Arabic-language text': 17,
#  'Herbalism': 17,
#  'Articles with dead external links from December 2016': 17,
#  'Nociceptin receptor agonists': 17,
#  'Opioid metabolites': 17,
#  'CS1 maint: DOI inactive as of October 2020': 17,
#  'Veterinary drugs': 17,
#  'CYP17A1 inhibitors': 17,
#  '5α-Reduced steroid metabolites': 17,
#  'Drug safety': 17,
#  'Progonadotropins': 17,
#  'CS1 Polish-language sources (pl)': 16,
#  'Mood stabilizers': 16,
#  'CS1 maint: location': 16,
#  'Articles needing additional references from July 2019': 16,
#  'Pharmacology stubs': 16,
#  'Hormones of the hypothalamus-pituitary-gonad axis': 16,
#  'Articles with unsourced statements from May 2020': 16,
#  'Spoken articles': 16,
#  'Articles with unsourced statements from November 2017': 16,
#  'Conjugated dienes': 16,
#  'Merck & Co. brands': 16,
#  'Medical controversies': 16,
#  '5-HT3 agonists': 15,
#  'Articles lacking reliable references from July 2014': 15,
#  'Opioid receptor ligands': 15,
#  'Tryptamine alkaloids': 15,
#  'Articles with unsourced statements from November 2020': 15,
#  '2,5-Dimethoxyphenethylamines': 15,
#  'Nitrobenzenes': 15,
#  'Catechol ethers': 15,
#  'Articles with unsourced statements from September 2016': 15,
#  'Indole alkaloids': 15,
#  'Aminoalkylindoles': 15,
#  'Harv and Sfn no-target errors': 15,
#  'Wikipedia articles with NLI identifiers': 15,
#  'Wikipedia articles with SUDOC identifiers': 15,
#  'Articles lacking reliable references from January 2019': 15,
#  'Experimental drugs': 15,
#  'Wikipedia articles needing clarification from October 2020': 15,
#  'Carbamates': 15,
#  'Articles with unsourced statements from April 2019': 15,
#  'Articles with unsourced statements from July 2017': 15,
#  'Enkephalinase inhibitors': 15,
#  'Opiates': 15,
#  'Anti-acne preparations': 15,
#  'Hair loss medications': 15,
#  'Racemate': 15,
#  'Hoffmann-La Roche brands': 15,
#  'Contraception for males': 15,
#  'Antiestrogens': 15,
#  'Substance dependence': 15,
#  'Chemical articles having a data page': 14,
#  'Anticholinesterases': 14,
#  'Eli Lilly and Company brands': 14,
#  'Use dmy dates from October 2020': 14,
#  'Articles with Finnish-language sources (fi)': 14,
#  'Articles with Italian-language sources (it)': 14,
#  'Isopropyl compounds': 14,
#  'Articles with unsourced statements from June 2017': 14,
#  'Diethylamino compounds': 14,
#  'Coordinates on Wikidata': 14,
#  'Use dmy dates from December 2019': 14,
#  'Commons category link is locally defined': 14,
#  'Articles containing Latin-language text': 14,
#  'Neurosteroids': 14,
#  'Phthalimides': 14,
#  'Glutarimides': 14,
#  'Spirolactones': 14,
#  'Articles with unsourced statements from August 2020': 13,
#  'Articles with unsourced statements from July 2018': 13,
#  'Articles with unsourced statements from August 2019': 13,
#  'Articles with unsourced statements from September 2015': 13,
#  'CS1 uses Japanese-language script (ja)': 13,
#  'Chemicals without a PubChem CID': 13,
#  'Articles with unsourced statements from October 2020': 13,
#  'Antiemetics': 13,
#  'Articles with unsourced statements from November 2016': 13,
#  'Combinations of psychoactive drugs': 13,
#  'Herbal and fungal hallucinogens': 13,
#  'Benzimidazoles': 13,
#  'Nootropics': 13,
#  'Anticonvulsants': 13,
#  'Alkaloids': 13,
#  'AbbVie brands': 13,
#  'All articles with style issues': 13,
#  'Articles with unsourced statements from July 2020': 13,
#  'Citrates': 13,
#  'Products introduced in 1960': 13,
#  'Transdermal patches': 13,
#  'Peptides': 13,
#  'Serotonin-norepinephrine reuptake inhibitors': 13,
#  'Antidiarrhoeals': 13,
#  '3β-Hydroxysteroid dehydrogenase inhibitors': 13,
#  'Prolactin releasers': 13,
#  'Testosterone': 13,
#  'Dienes': 13,
#  'Psychiatric diagnosis': 13,
#  'Articles with unsourced statements from August 2015': 12,
#  'Articles with unsourced statements from February 2016': 12,
#  'Pages with reference errors': 12,
#  'All Wikipedia articles needing clarification': 12,
#  'CS1 Danish-language sources (da)': 12,
#  'Pages with non-numeric formatnum arguments': 12,
#  'Tert-butyl compounds': 12,
#  'Oneirogens': 12,
#  'Cyclohexenes': 12,
#  'Articles with unsourced statements from June 2019': 12,
#  'Gastrointestinal system drug stubs': 12,
#  'Articles with long short description': 12,
#  'Schering-Plough brands': 12,
#  'Articles with dead external links from July 2019': 12,
#  '20th-century health disasters': 12,
#  'Chirality': 12,
#  'Congenital amputations': 12,
#  'Health disasters in the United Kingdom': 12,
#  'History of disability': 12,
#  'Immunosuppressants': 12,
#  'Leprosy': 12,
#  'Medical scandals': 12,
#  'Steroids': 12,
#  'All set index articles': 11,
#  'Articles with unsourced statements from February 2013': 11,
#  'Cathinones': 11,
#  'Articles with unsourced statements from April 2017': 11,
#  'Organobromides': 11,
#  'Cyclobutanes': 11,
#  'Psychedelia': 11,
#  'Articles containing Greek-language text': 11,
#  'Psychedelic drug advocates': 11,
#  'Wikipedia articles with SNAC-ID identifiers': 11,
#  'Naphthalenes': 11,
#  'Drug control law': 11,
#  'Webarchive template archiveis links': 11,
#  'CS1 maint: numeric names: authors list': 11,
#  'Articles with unsourced statements from April 2016': 11,
#  'Use dmy dates from September 2020': 11,
#  'Articles with unsourced statements from June 2016': 11,
#  'Furans': 11,
#  'Genes on human chromosome 8': 11,
#  'Heroin': 11,
#  'Biased ligands': 11,
#  'Hair removal': 11,
#  'Articles with unsourced statements from December 2016': 11,
#  'English-language films': 11,
#  'Sedative stubs': 11,
#  'Articles needing additional references from June 2019': 10,
#  'Cannabis-related lists': 10,
#  'Webarchive template other archives': 10,
#  'Articles with dead external links from March 2018': 10,
#  'Use dmy dates from November 2018': 10,
#  'Articles with unsourced statements from November 2010': 10,
#  'Use dmy dates from July 2020': 10,
#  'Articles with unsourced statements from March 2020': 10,
#  'Carboxylic acids': 10,
#  'Wikipedia articles with BIBSYS identifiers': 10,
#  'Chemical articles with multiple PubChem CIDs': 10,
#  'Norepinephrine releasing agents': 10,
#  'Convulsants': 10,
#  'Articles with unsourced statements from January 2018': 10,
#  'Steroid hormones': 10,
#  'Morphine': 10,
#  'African-American culture': 10,
#  'Infobox drug with local INN variant': 10,
#  'Articles with unsourced statements from March 2013': 10,
#  'Serotonin antagonists': 10,
#  'Combination analgesics': 10,
#  'Dermatologic drug stubs': 10,
#  'Cyclopentanols': 10,
#  'Androgen ethers': 10,
#  'American films': 10,
#  'Album articles lacking alt text for covers': 10,
#  'CS1 Norwegian-language sources (no)': 9,
#  'Neurotransmitters': 9,
#  'Chemical classes of psychoactive drugs': 9,
#  '5-HT1A agonists': 9,
#  'Articles with unsourced statements from July 2012': 9,
#  'Articles with unsourced statements from September 2018': 9,
#  'Commons link is on Wikidata': 9,
#  'Lysergic acid diethylamide': 9,
#  'Articles with unsourced statements from January 2020': 9,
#  'Articles with unsourced statements from April 2018': 9,
#  'Articles with unsourced statements from December 2014': 9,
#  'Ayahuasca': 9,
#  'Aphrodisiacs': 9,
#  'Articles with unsourced statements from March 2019': 9,
#  'Benzoate esters': 9,
#  'Articles with unsourced statements from January 2013': 9,
#  'Articles with unsourced statements from September 2019': 9,
#  'Articles with unsourced statements from May 2019': 9,
#  'All articles with topics of unclear notability': 9,
#  'Neurotoxins': 9,
#  'Pyrazolecarboxamides': 9,
#  'Endocannabinoid reuptake inhibitors': 9,
#  'Fatty acid amides': 9,
#  'Articles with unsourced statements from May 2018': 9,
#  'Wikipedia articles with NLA identifiers': 9,
#  'Taxa named by Carl Linnaeus': 9,
#  'Plant toxins': 9,
#  'Use dmy dates from April 2020': 9,
#  '21-Hydroxylase inhibitors': 9,
#  'Articles with dead external links from April 2020': 9,
#  'All articles needing expert attention': 9,
#  'Psychedelic drug research': 9,
#  'Dopamine reuptake inhibitors': 9,
#  'Phenyl compounds': 9,
#  'Culture of Houston': 9,
#  'Culture of the Southern United States': 9,
#  'Mixed drinks': 9,
#  'Use mdy dates from January 2018': 9,
#  'Respiratory system drug stubs': 9,
#  'Articles with unsourced statements from October 2016': 9,
#  'All orphaned articles': 9,
#  'Articles with unsourced statements from November 2011': 9,
#  '11β-Hydroxylase inhibitors': 9,
#  'Doping in sport': 9,
#  'Human female endocrine system': 9,
#  'Use dmy dates from March 2014': 9,
#  'RTTNEURO': 9,
#  'Triazolobenzodiazepines': 9,
#  'Articles containing Spanish-language text': 8,
#  '5-HT2B agonists': 8,
#  'Articles with unsourced statements from April 2015': 8,
#  'Use dmy dates from August 2017': 8,
#  'Novartis brands': 8,
#  'Articles lacking reliable references from February 2020': 8,
#  'Articles with dead external links from July 2018': 8,
#  'Wikipedia articles needing clarification from March 2014': 8,
#  'Treatment and management of attention deficit hyperactivity disorder': 8,
#  'CS1 Hungarian-language sources (hu)': 8,
#  'Indanes': 8,
#  'Diisopropylamino compounds': 8,
#  'Mycotoxins': 8,
#  'Use dmy dates from November 2020': 8,
#  'Adamantanes': 8,
#  'Benzoylindoles': 8,
#  'Official website different in Wikidata and Wikipedia': 8,
#  'Resorcinols': 8,
#  'Psychedelic drug researchers': 8,
#  'Wikipedia articles with Trove identifiers': 8,
#  'Articles containing French-language text': 8,
#  'Featured articles': 8,
#  'Antidotes': 8,
#  'CS1 maint: unfit url': 8,
#  'Selective ERβ agonists': 8,
#  'G protein-coupled receptors': 8,
#  'Phenylacetylindoles': 8,
#  'Sulfonamides': 8,
#  'Articles with unsourced statements from August 2009': 8,
#  'Harv and Sfn multiple-target errors': 8,
#  'Articles containing potentially dated statements from 2011': 8,
#  'Articles with dead external links from January 2020': 8,
#  'Articles with unsourced statements from January 2017': 8,
#  'Hallucinations': 8,
#  'Articles with unsourced statements from December 2018': 8,
#  'Articles containing Russian-language text': 8,
#  'Sterols': 8,
#  'History of drug control': 8,
#  'Phenol esters': 8,
#  'Psychoactive drugs': 8,
#  'Nociceptin receptor antagonists': 8,
#  'Benzyl compounds': 8,
#  'Articles with unsourced statements from October 2017': 8,
#  'Alkylating agents': 8,
#  'Antiandrogen esters': 8,
#  'Benzhydryl compounds': 8,
#  'Articles with unsourced statements from November 2019': 8,
#  'Articles containing potentially dated statements from 2013': 8,
#  'Alcohol abuse': 8,
#  'Experimental cancer drugs': 8,
#  '1-Ethynylcyclopentanols': 8,
#  '1-Methylcyclopentanols': 8,
#  'Antiandrogens': 8,
#  'Antiglucocorticoids': 8,
#  'Bodybuilding': 8,
#  'Imidazolidines': 8,
#  'Drug policy of the United States': 8,
#  'Year of birth missing (living people)': 8,
#  'Illegal drug trade': 8,
#  'Template film date with 2 release dates': 8,
#  'Corticosteroids': 8,
#  'Drugs in sport in the United States': 8,
#  'Barbiturates': 8,
#  'Articles with unsourced statements from October 2013': 7,
#  'Infobox-drug molecular-weight unexpected-character': 7,
#  'Pages with URL errors': 7,
#  'Articles with unsourced statements from January 2015': 7,
#  'Pages with duplicate reference names': 7,
#  'Articles needing additional references from September 2020': 7,
#  'Psychoactive fungi': 7,
#  'Carbonic anhydrase activators': 7,
#  'Articles with unsourced statements from March 2012': 7,
#  'Vasoconstrictors': 7,
#  'CS1 Latvian-language sources (lv)': 7,
#  'Articles with unsourced statements from March 2014': 7,
#  'Tetramethylcyclopropanoylindoles': 7,
#  'Articles with unsourced statements from December 2020': 7,
#  'Articles needing additional references from August 2019': 7,
#  'Articles needing additional medical references from August 2020': 7,
#  'Articles with unsourced statements from May 2016': 7,
#  'Psychedelic music': 7,
#  'HU cannabinoids': 7,
#  'Ergogenic aids': 7,
#  'Wikipedia articles with MusicBrainz area identifiers': 7,
#  'CS1 maint: DOI inactive as of December 2020': 7,
#  'Signal transduction': 7,
#  'CS1 errors: dates': 7,
#  'Articles with dead external links from July 2020': 7,
#  'Articles with dead external links from June 2016': 7,
#  'Articles with unsourced statements from May 2014': 7,
#  'GPER agonists': 7,
#  'Wikipedia articles with WorldCat-VIAF identifiers': 7,
#  'NMDA receptor agonists': 7,
#  'Articles with unsourced statements from February 2019': 7,
#  'Articles with unsourced statements from June 2018': 7,
#  'Gonadotropin-releasing hormone and gonadotropins': 7,
#  'Human hormones': 7,
#  'Merck brands': 7,
#  'Articles with unsourced statements from April 2010': 7,
#  'Articles with unsourced statements from May 2017': 7,
#  'Azepanes': 7,
#  'Nitrogen heterocycles': 7,
#  'Wikipedia pending changes protected pages': 7,
#  'Articles with unsourced statements from December 2013': 7,
#  'All articles needing rewrite': 7,
#  'Articles needing additional references from November 2016': 7,
#  'Articles with dead external links from December 2017': 7,
#  'Proteinogenic amino acids': 7,
#  'Alkaloid stubs': 7,
#  'Ureas': 7,
#  'Acetanilides': 7,
#  'Tricyclic antidepressants': 7,
#  'Human metabolites': 7,
#  'Chemical elements': 7,
#  'Wikipedia articles needing page number citations from September 2010': 7,
#  'Articles unintentionally citing retracted publications': 7,
#  'Thioureas': 7,
#  '2,2-Bis(4-hydroxyphenyl)propanes': 7,
#  'Xenoestrogens': 7,
#  'Enanthate esters': 7,
#  'Drug control law in the United States': 7,
#  'Cannabis stubs': 7,
#  'Pharmaceuticals policy': 7,
#  'Cocaine in the United States': 7,
#  'Major League Baseball controversies': 7,
#  'Pages using multiple image with manual scaled images': 6,
#  'History of cannabis': 6,
#  'Articles containing German-language text': 6,
#  'Articles with unsourced statements from August 2018': 6,
#  'Mescalines': 6,
#  'Psychedelic tryptamine carriers': 6,
#  'Sympathomimetics': 6,
#  'Local anesthetics': 6,
#  'Tropane alkaloids found in Erythroxylum coca': 6,
#  'Articles needing additional references from April 2015': 6,
#  'Resorcinol ethers': 6,
#  'Articles with unsourced statements from November 2013': 6,
#  '5-Benzofuranethanamines': 6,
#  '6-Benzofuranethanamines': 6,
#  'Acetylcholinesterase inhibitors': 6,
#  'Hydrazides': 6,
#  'Coordinates not on Wikidata': 6,
#  'Pharmacodynamics': 6,
#  'Wikipedia articles with CINII identifiers': 6,
#  'Wikipedia articles with NLP identifiers': 6,
#  'Wikipedia articles with SELIBR identifiers': 6,
#  'Wikipedia articles incorporating a citation from the 1911 Encyclopaedia Britannica with Wikisource reference': 6,
#  'Russian drugs': 6,
#  'Commons link from Wikidata': 6,
#  'Drugs acting on the cardiovascular system': 6,
#  'Drugs acting on the nervous system': 6,
#  'Esters': 6,
#  'Articles with unsourced statements from November 2015': 6,
#  'Phytoestrogens': 6,
#  'Articles with unsourced statements from August 2013': 6,
#  'Aromatic ketones': 6,
#  'Use dmy dates from September 2019': 6,
#  'Genes on human chromosome 6': 6,
#  'Wikipedia articles incorporating text from the United States National Library of Medicine': 6,
#  'CS1 maint: ref=harv': 6,
#  'Articles with unsourced statements from September 2014': 6,
#  'Articles with unsourced statements from October 2014': 6,
#  'Articles with dead external links from May 2020': 6,
#  'Articles with unsourced statements from September 2013': 6,
#  'History of pharmacy': 6,
#  'Use dmy dates from May 2020': 6,
#  'Isoxazoles': 6,
#  'Peptide hormones': 6,
#  'Articles with dead external links from February 2020': 6,
#  'Pages with broken reference names': 6,
#  'Butyrates': 6,
#  'All articles covered by WikiProject Wikify': 6,
#  'Articles with dead external links from September 2017': 6,
#  'Tropanes': 6,
#  'Articles with unsourced statements from August 2016': 6,
#  'Articles with unsourced statements from June 2010': 6,
#  'American drug traffickers': 6,
#  'TSPO ligands': 6,
#  'Oripavines': 6,
#  'Irreversible receptor antagonists': 6,
#  'Nicotinate esters': 6,
#  'Glucogenic amino acids': 6,
#  'H1 receptor antagonists': 6,
#  'Anilines': 6,
#  'Use dmy dates from April 2019': 6,
#  'Cyclopentanes': 6,
#  'Plants described in 1753': 6,
#  'Articles with dead external links from August 2019': 6,
#  'Chemicals that do not have a ChemSpider ID assigned': 6,
#  'Reducing agents': 6,
#  'Pages using web citations with no URL': 6,
#  'Articles with unsourced statements from August 2011': 6,
#  'Herbs': 6,
#  'Hormones of the suprarenal cortex': 6,
#  'Animal reproductive system': 6,
#  'Aldosterone synthase inhibitors': 6,
#  'Cholesterol side-chain cleavage enzyme inhibitors': 6,
#  'Antiprogestogens': 6,
#  'Testosterone esters': 6,
#  'Pages in non-existent country centric categories': 6,
#  'All Wikipedia articles written in Australian English': 6,
#  'Adverse effects of psychoactive drugs': 6,
#  'Cyclopyrrolones': 6,
#  'Imidazobenzodiazepines': 6,
#  'Articles with unsourced statements from May 2012': 5,
#  'Use dmy dates from July 2013': 5,
#  'Articles containing potentially dated statements from October 2015': 5,
#  'Preparations of cannabis': 5,
#  'Counterculture of the 1960s': 5,
#  'Native American Church': 5,
#  'Articles needing additional medical references from June 2017': 5,
#  'Articles with dead external links from September 2019': 5,
#  'Articles with unsourced statements from January 2012': 5,
#  'Articles containing potentially dated statements from December 2019': 5,
#  'Excitatory amino acid reuptake inhibitors': 5,
#  'Methamphetamine': 5,
#  'Use American English from December 2017': 5,
#  'Articles needing additional references from January 2016': 5,
#  'Articles with unsourced statements from April 2012': 5,
#  'Articles needing additional references from September 2019': 5,
#  'Articles with dead external links from April 2019': 5,
#  'Articles with unsourced statements from November 2018': 5,
#  'O-Methylated phenols': 5,
#  'Articles needing additional references from January 2017': 5,
#  'Articles needing additional references from November 2013': 5,
#  'Articles with unsourced statements from March 2015': 5,
#  'Articles with unsourced statements from November 2012': 5,
#  'Use dmy dates from June 2013': 5,
#  'Articles with unsourced statements from September 2011': 5,
#  'Articles with dead external links from November 2017': 5,
#  'Articles needing additional references from March 2011': 5,
#  'Indole ethers at the benzene ring': 5,
#  'Articles with unsourced statements from February 2014': 5,
#  'Articles with unsourced statements from March 2009': 5,
#  'Quinolines': 5,
#  'Articles with unsourced statements from January 2016': 5,
#  'Articles with unsourced statements from February 2017': 5,
#  'Thiazoles': 5,
#  'Cyclohexanes': 5,
#  'Articles with unsourced statements from June 2015': 5,
#  'Organophosphates': 5,
#  'Drug policy reform activists': 5,
#  'Wikipedia articles with HDS identifiers': 5,
#  'All articles that are too technical': 5,
#  'Taxonbars with automatically added basionyms': 5,
#  'Pages including recorded pronunciations': 5,
#  'Articles with unsourced statements from March 2018': 5,
#  'Articles with unsourced statements from May 2015': 5,
#  'Articles with unsourced statements from December 2015': 5,
#  'Articles with unsourced statements from January 2010': 5,
#  'Simple aromatic rings': 5,
#  'Articles with unsourced statements from February 2015': 5,
#  'CS1 Finnish-language sources (fi)': 5,
#  'Wikipedia articles needing clarification from May 2016': 5,
#  'Pages using refbegin with normalfont parameter': 5,
#  'Articles with unsourced statements from June 2011': 5,
#  'Drugs': 5,
#  'All articles with self-published sources': 5,
#  'Chembox having DSD data': 5,
#  'Dietary supplements': 5,
#  'Steroid sulfotransferase inhibitors': 5,
#  'Alkaloids found in Iboga': 5,
#  'Use dmy dates from April 2017': 5,
#  'Use dmy dates from August 2020': 5,
#  'WIN compounds': 5,
#  'Glycoproteins': 5,
#  'CS1 uses Russian-language script (ru)': 5,
#  'Articles needing additional references from August 2016': 5,
#  'Articles needing additional references from November 2012': 5,
#  'Articles with unsourced statements from October 2008': 5,
#  'Articles needing additional references from June 2018': 5,
#  'Use dmy dates from January 2014': 5,
#  'Imidazoles': 5,
#  'Articles containing potentially dated statements from 2016': 5,
#  'Articles with unsourced quotes': 5,
#  'Wikipedia articles needing clarification from February 2020': 5,
#  'Articles needing additional references from March 2017': 5,
#  'Functional groups': 5,
#  'Articles with unsourced statements from April 2013': 5,
#  'Articles with dead external links from April 2018': 5,
#  'Articles needing additional references from April 2011': 5,
#  'Wikipedia articles with NLK identifiers': 5,
#  'Opioid receptors': 5,
#  'Ketogenic amino acids': 5,
#  'Dopamine antagonists': 5,
#  'Drugs acting on the gastrointestinal system and metabolism': 5,
#  'Precursor proteins': 5,
#  'Dog medications': 5,
#  'Glucuronide esters': 5,
#  'Equine medications': 5,
#  'Neuroprotective agents': 5,
#  'Potassium channel blockers': 5,
#  'Benzazocines': 5,
#  'Norepinephrine reuptake inhibitors': 5,
#  'Thioesters': 5,
#  'Use dmy dates from November 2017': 5,
#  'Chembox container only': 5,
#  'Norepinephrine-dopamine reuptake inhibitors': 5,
#  'Use dmy dates from December 2017': 5,
#  'Genes on human chromosome 2': 5,
#  'Drugs with non-standard pregnancy category': 5,
#  'Exercise physiology': 5,
#  '1-Ethylcyclopentanols': 5,
#  'Organosulfur compounds': 5,
#  'Endocrine system': 5,
#  'Drugs for benign prostatic hyperplasia': 5,
#  'Selective estrogen receptor modulators': 5,
#  'Caproate esters': 5,
#  'Clinical pharmacology': 5,
#  'Cardiovascular system drug stubs': 5,
#  'Bayer brands': 5,
#  'Halohydrins': 5,
#  'Hormones of the pregnant female': 5,
#  'Hemp': 5,
#  'Cannabis in the United States': 5,
#  'Cannabis law in the United States': 5,
#  'American cannabis activists': 5,
#  'Use mdy dates from March 2019': 5,
#  'Smuggling': 5,
#  'Drug Enforcement Administration': 5,
#  'Substance abuse': 5,
#  'Colombian drug traffickers': 5,
#  'Colombian mob bosses': 5,
#  'Medellín Cartel traffickers': 5,
#  'Pages using certification Table Entry with streaming figures': 5,
#  'Pages using certification Table Entry with streaming footnote': 5,
#  'Films about cocaine': 5,
#  'All BLP articles lacking sources': 5,
#  'Doping in baseball': 5,
#  'Opioid epidemic': 5,
#  'Withdrawal syndromes': 5,
#  'Addiction psychiatry': 5,
#  'Nonbenzodiazepines': 5,
#  'Abnormal psychology': 5,
#  'Muscle relaxants': 4,
#  'Vague or ambiguous time from January 2015': 4,
#  'Wikipedia articles needing factual verification from October 2014': 4,
#  'Wikipedia articles needing page number citations from September 2015': 4,
#  'Dynamic lists': 4,
#  'Wikipedia semi-protected pages': 4,
#  'Phenethylamine alkaloids': 4,
#  'Articles lacking reliable references from June 2018': 4,
#  'Articles containing potentially dated statements from 2005': 4,
#  'Articles containing potentially dated statements from 2007': 4,
#  'Articles with disputed statements from March 2019': 4,
#  'Articles with unsourced statements from September 2009': 4,
#  'Otologicals': 4,
#  'Sympathomimetic amines': 4,
#  'Hydroxyarenes': 4,
#  'PET radiotracers': 4,
#  'Nitro compounds': 4,
#  'All articles with empty sections': 4,
#  'Articles with Japanese-language sources (ja)': 4,
#  'Articles needing additional references from August 2018': 4,
#  'Enzyme inhibitors': 4,
#  'Biological sources of psychoactive drugs': 4,
#  'Articles lacking in-text citations from June 2013': 4,
#  'Benzofuran ethers at the benzene ring': 4,
#  'Chemicals that do not have a CAS registry number assigned': 4,
#  'Chromenes': 4,
#  'Wikipedia articles needing page number citations from January 2014': 4,
#  'Articles lacking reliable references from August 2020': 4,
#  'Use dmy dates from January 2013': 4,
#  'Articles needing additional references from April 2018': 4,
#  'American rock music genres': 4,
#  'Psychedelic rock': 4,
#  'Articles with specifically marked weasel-worded phrases from September 2015': 4,
#  'Life sciences industry': 4,
#  'Wikipedia articles with LNB identifiers': 4,
#  'Wikipedia articles with RERO identifiers': 4,
#  'CS1 Latin-language sources (la)': 4,
#  'Drugs in sport': 4,
#  'Tropane alkaloids': 4,
#  'Drug overdose': 4,
#  'Substance intoxication': 4,
#  'Articles with unsourced statements from November 2014': 4,
#  'CS1 Indonesian-language sources (id)': 4,
#  'Articles containing potentially dated statements from March 2020': 4,
#  'Articles containing potentially dated statements from September 2019': 4,
#  'Natural phenols': 4,
#  'Pop music genres': 4,
#  'Subcultures': 4,
#  'Harm reduction': 4,
#  'Wikipedia articles in need of updating from November 2020': 4,
#  'Psychedelic phenethylamine carriers': 4,
#  'Psychoactive cacti': 4,
#  'Articles with unsourced statements from May 2010': 4,
#  'Drug classes defined by psychological effects': 4,
#  'Wikipedia articles needing page number citations from August 2016': 4,
#  'Ergot alkaloids': 4,
#  '20th-century American male actors': 4,
#  'Grammy Award winners': 4,
#  'Psychedelic art': 4,
#  'Flavonoid antioxidants': 4,
#  'CS1 errors: external links': 4,
#  'Epoxides': 4,
#  'Alkaloids found in Apocynaceae': 4,
#  'Articles with unsourced statements from November 2008': 4,
#  'Cannabis by country': 4,
#  'Use dmy dates from March 2020': 4,
#  'Articles containing potentially dated statements from 2010': 4,
#  'Articles needing additional references from September 2015': 4,
#  'British rock music genres': 4,
#  'Articles needing additional references from June 2015': 4,
#  'Phenylpiperazines': 4,
#  'Articles with unsourced statements from August 2010': 4,
#  'Articles with unsourced statements from July 2016': 4,
#  'Articles containing potentially dated statements from 2020': 4,
#  'Articles with unsourced statements from August 2017': 4,
#  'Drug discovery': 4,
#  'Articles needing expert attention with no reason or talk parameter': 4,
#  'Articles with dead external links from October 2010': 4,
#  'Slang': 4,
#  'Articles with unsourced statements from July 2010': 4,
#  'Biphenyls': 4,
#  'Articles with failed verification from July 2019': 4,
#  'Sigma receptor ligands': 4,
#  'Aromatic compound stubs': 4,
#  'Flavones': 4,
#  'Guanidines': 4,
#  'Wikipedia articles in need of updating from May 2020': 4,
#  'Tetrahydroisoquinolines': 4,
#  'Aromatic amino acids': 4,
#  'Essential amino acids': 4,
#  'Opium': 4,
#  'Articles needing additional medical references from November 2013': 4,
#  'Alpha blockers': 4,
#  'American inventions': 4,
#  'PubChem ID (CID) same as Wikidata': 4,
#  'Use dmy dates from June 2018': 4,
#  'Dimers (chemistry)': 4,
#  'Catechols': 4,
#  'Flavanols': 4,
#  'Nitrogen mustards': 4,
#  'Articles needing additional references from June 2016': 4,
#  'All Wikipedia articles written in Indian English': 4,
#  '5-HT2C antagonists': 4,
#  'Articles with unsourced statements from March 2011': 4,
#  'Wikipedia articles incorporating a citation from the New International Encyclopedia': 4,
#  'Articles to be expanded from December 2018': 4,
#  'Use dmy dates from February 2015': 4,
#  'Articles containing Japanese-language text': 4,
#  'Use dmy dates from September 2017': 4,
#  'Drugs in the Soviet Union': 4,
#  'Natural opium alkaloids': 4,
#  '5-HT3 antagonists': 4,
#  'Pages using div col with small parameter': 4,
#  'Alpha-2 blockers': 4,
#  'Use dmy dates from October 2016': 4,
#  'Companies listed on NASDAQ': 4,
#  'Pharmaceutical companies of the United States': 4,
#  'AstraZeneca brands': 4,
#  'Takeda Pharmaceutical Company brands': 4,
#  'Protein families': 4,
#  'Papaver': 4,
#  'Non-food crops': 4,
#  'Selective progesterone receptor modulators': 4,
#  'Spironolactone': 4,
#  'Use dmy dates from November 2019': 4,
#  'IARC Group 2A carcinogens': 4,
#  'Nandrolone esters': 4,
#  ...}

# %%
#According to the categories in the list above the following categories could be scraped for high precision articles
'''
'Androgens and anabolic steroids', 'Drugs with non-standard legal status', 'Designer drugs', 'Mu-opioid agonists', 
'Synthetic opioids', 'Opioids', 'Cannabinoids', 'Cannabinoid stubs', 'Morphinans', 'Euphoriants', 'Steroid stubs',
'World Anti-Doping Agency prohibited substances', 'Serotonin receptor agonists', 'Substituted amphetamines', 
'Abandoned drugs', 'Semisynthetic opioids', 'Progestogens', 'Opioid antagonists', 'Psychedelic tryptamines', 
'World Health Organization essential medicines', 'Psychoactive drug stubs', 'Opioid peptides', 'Drug-related lists',
'Benzodioxoles', 'Hallucinogen stubs', 'Serotonin-norepinephrine-dopamine releasing agents', 'Steroidal antiandrogens', 
'Benzodiazepines', 'Drug culture', 'Dissociative drugs', 'Fentanyl', 'Psychedelic drugs', 'Methamphetamines',
'25-NB (psychedelics)', 'Cocaine', 'Cannabis', 'Drug safety', 'Opioid metabolites'



Maybe:'Androstanes', 'Phenols', 'Analgesics'
'''
# Out:
# "\n'Androgens and anabolic steroids', 'Drugs with non-standard legal status', 'Designer drugs', 'Mu-opioid agonists', \n'Synthetic opioids', 'Opioids', 'Cannabinoids', 'Cannabinoid stubs', 'Morphinans', 'Euphoriants', 'Steroid stubs',\n'World Anti-Doping Agency prohibited substances', 'Serotonin receptor agonists', 'Substituted amphetamines', \n'Abandoned drugs', 'Semisynthetic opioids', 'Progestogens', 'Opioid antagonists', 'Psychedelic tryptamines', \n'World Health Organization essential medicines', 'Psychoactive drug stubs', 'Opioid peptides', 'Drug-related lists',\n'Benzodioxoles', 'Hallucinogen stubs', 'Serotonin-norepinephrine-dopamine releasing agents', 'Steroidal antiandrogens', \n'Benzodiazepines', 'Drug culture', 'Dissociative drugs', 'Fentanyl', 'Psychedelic drugs', 'Methamphetamines',\n'25-NB (psychedelics)', 'Cocaine', 'Cannabis', 'Drug safety', 'Opioid metabolites'\n\n\n\nMaybe:'Androstanes', 'Phenols', 'Analgesics'\n"

# %%
#Store Dataframe for annoation
text_corpus.to_pickle('data/textCorpusV0.2')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 500)
pd.set_option('display.max_colwidth', None)#400
unique_links
# Out:
# ['GHB',
#  'Benzodiazepine',
#  'MDMA Drug',
#  'Phencyclidine',
#  'Ketamine',
#  'Hashish',
#  'List of names for cannabis strains',
#  'Cannabis strain',
#  'Cannabis edible',
#  'Cannabis concentrate',
#  'Lysergic acid diethylamide',
#  'Mescaline',
#  'Psilocybin mushroom',
#  'N,N-Dimethyltryptamine',
#  'Methamphetamine',
#  'Cocaine',
#  '(C6)-CP 47,497',
#  '(C9)-CP 47,497',
#  '1-Butyl-3-(2-methoxybenzoyl)indole',
#  '1-Butyl-3-(4-methoxybenzoyl)indole',
#  '1-Methylpsilocin',
#  '1-Pentyl-3-(2-methoxybenzoyl)indole',
#  '11-Hydroxy-THC',
#  '1P-ETH-LAD',
#  '1P-LSD',
#  '1cP-LSD',
#  '2,3-Methylenedioxyamphetamine',
#  '2,5-Dimethoxy-4-chloroamphetamine',
#  '2,5-Dimethoxy-4-ethylamphetamine',
#  '2,5-Dimethoxy-4-isopropylamphetamine',
#  '2,5-Dimethoxy-4-nitroamphetamine',
#  '2,5-Dimethoxy-4-propylamphetamine',
#  '2,5-dimethoxy-4-bromoamphetamine',
#  '2,5-dimethoxy-4-iodoamphetamine',
#  '2,5-dimethoxy-4-methylamphetamine',
#  '2,alpha-DMT',
#  '2-Bromo-4,5-methylenedioxyamphetamine',
#  '2-Me-DET',
#  '2-Methyl-DMT',
#  '25B-NBF',
#  '25B-NBOH',
#  '25C-NBF',
#  '25C-NBOH',
#  '25CN-NBOH',
#  '25CN-NBOMe',
#  '25I-NBF',
#  '25I-NBMD',
#  '25I-NBOH',
#  '25I-NBOMe',
#  '25N-NBOMe',
#  '25P-NBOMe',
#  '25iP-NBOMe',
#  '2C-B',
#  '2C-B-BUTTERFLY',
#  '2C-B-FLY',
#  '2C-B-NBOMe',
#  '2C-BCB',
#  '2C-C',
#  '2C-C-NBOMe',
#  '2C-D',
#  '2C-D-NBOMe',
#  '2C-E',
#  '2C-E-NBOMe',
#  '2C-EF',
#  '2C-F',
#  '2C-G',
#  '2C-G-NBOMe',
#  '2C-H',
#  '2C-H-NBOMe',
#  '2C-I',
#  '2C-I-NBOMe',
#  '2C-N',
#  '2C-O',
#  '2C-O-4',
#  '2C-P',
#  '2C-SE',
#  '2C-T',
#  '2C-T-13',
#  '2C-T-15',
#  '2C-T-16',
#  '2C-T-17',
#  '2C-T-19',
#  '2C-T-2',
#  '2C-T-21',
#  '2C-T-4',
#  '2C-T-4-NBOMe',
#  '2C-T-7',
#  '2C-T-7-NBOMe',
#  '2C-T-8',
#  '2C-T-NBOMe',
#  '2C-TFM',
#  '2C-TFM-NBOMe',
#  '2C-YN',
#  '2C-iP',
#  '2CB-Ind',
#  '2CBCB-NBOMe',
#  '2CBFly-NBOMe',
#  '2CD-5EtO',
#  '2C (psychedelics)',
#  '3,4-methylenedioxyamphetamine',
#  '3-Methoxy-4-ethoxyphenethylamine',
#  '3-Methoxy-4-methylamphetamine',
#  '3-Methylmethcathinone',
#  '3C-BZ',
#  '3C-DFE',
#  '3C-E',
#  '3C-P',
#  '4,5-DHP-AMT',
#  '4,5-DHP-DMT',
#  '4,5-MDO-DMT',
#  '4,5-MDO-DiPT',
#  '4-AcO-DALT',
#  '4-AcO-DET',
#  '4-AcO-DPT',
#  '4-AcO-DiPT',
#  '4-AcO-EiPT',
#  '4-AcO-MALT',
#  '4-AcO-MET',
#  '4-Acetoxy-MiPT',
#  '4-Bromo-3,5-dimethoxyamphetamine',
#  '4-D (psychedelic)',
#  '4-Desoxymescaline',
#  '4-Ethylamphetamine',
#  '4-Ethylmethcathinone',
#  '4-Fluoroamphetamine',
#  '4-HO-DALT',
#  '4-HO-DBT',
#  '4-HO-DET',
#  '4-HO-DPT',
#  '4-HO-DSBT',
#  '4-HO-DiPT',
#  '4-HO-MALT',
#  '4-HO-MET',
#  '4-HO-MPMI',
#  '4-HO-MPT',
#  '4-HO-MiPT',
#  '4-HO-pyr-T',
#  '4-HO-αMT',
#  '4-HTMPIPO',
#  '4-Hydroxy-5-methoxydimethyltryptamine',
#  '4-Me-αMT',
#  '4-MeO-DMT',
#  '4-MeO-MiPT',
#  '4-Methyl-αET',
#  '4-Methylmethamphetamine',
#  '4-Methylphenylisobutylamine',
#  '4-Methylthioamphetamine',
#  '4-Nonylphenylboronic acid',
#  '4-chlorophenylisobutylamine',
#  '4-fluoro-5-methoxy-DMT',
#  '5,6-MDO-DiPT',
#  '5,6-MDO-MiPT',
#  '5-APB',
#  '5-APDB',
#  '5-Bromo-DMT',
#  '5-EAPB',
#  '5-Fluoro-AMT',
#  '5-HO-DiPT',
#  '5-Iodo-2-aminoindane',
#  '5-MAPB',
#  '5-MAPDB',
#  '5-MBPB',
#  '5-Me-MiPT',
#  '5-MeO-2-TMT',
#  '5-MeO-7-TMT',
#  '5-MeO-AET',
#  '5-MeO-AMT',
#  '5-MeO-DALT',
#  '5-MeO-DET',
#  '5-MeO-DMT',
#  '5-MeO-DPT',
#  '5-MeO-DiBF',
#  '5-MeO-DiPT',
#  '5-MeO-EPT',
#  '5-MeO-EiPT',
#  '5-MeO-MALT',
#  '5-MeO-MET',
#  '5-MeO-MPMI',
#  '5-MeO-MPT',
#  '5-MeO-MiPT',
#  '5-MeO-NMT',
#  '5-MeO-PiPT',
#  '5-MeO-pyr-T',
#  '5-MeS-DMT',
#  '5-Methyl-DMT',
#  '5-Methyl-MDA',
#  '5Br-UR-144',
#  '5Cl-APINACA',
#  '5Cl-UR-144',
#  '5F-3-pyridinoylindole',
#  '5F-AB-FUPPYCA',
#  '5F-ADB',
#  '5F-ADB-PINACA',
#  '5F-ADBICA',
#  '5F-AMB',
#  '5F-APINACA',
#  '5F-CUMYL-PINACA',
#  '5F-EMB-PINACA',
#  '5F-NNE1',
#  '5F-PB-22',
#  '5F-PCN',
#  '5F-PY-PICA',
#  '5F-PY-PINACA',
#  '5F-SDB-006',
#  '6-APB',
#  '6-APDB',
#  '6-CAT',
#  '6-EAPB',
#  '6-Fluoro-DMT',
#  '6-MAPB',
#  '6-MAPDB',
#  '6-fluoro-AMT',
#  '7-Methyl-DMT',
#  '7-Methyl-αET',
#  '9-nor-9ß-Hydroxyhexahydrocannabinol',
#  'A-40174',
#  'A-41988',
#  'A-42574',
#  'A-796,260',
#  'A-834,735',
#  'A-836,339',
#  'A-955,840',
#  'AB-001',
#  'AB-CHFUPYCA',
#  'AB-CHMFUPPYCA',
#  'AB-CHMINACA',
#  'AB-FUBICA',
#  'AB-FUBINACA',
#  'AB-FUBINACA 2-fluorobenzyl isomer',
#  'AB-PICA',
#  'AB-PINACA',
#  'ADAMANTYL-THPINACA',
#  'ADB-CHMINACA',
#  'ADB-FUBICA',
#  'ADB-FUBINACA',
#  'ADB-PINACA',
#  'ADBICA',
#  'ADSB-FUB-187',
#  'AEM (psychedelic)',
#  'AL-LAD',
#  'ALD-52',
#  'AM-087',
#  'AM-1220',
#  'AM-1221',
#  'AM-1235',
#  'AM-1241',
#  'AM-1248',
#  'AM-1346',
#  'AM-1387',
#  'AM-1714',
#  'AM-2201',
#  'AM-2232',
#  'AM-2233',
#  'AM-2389',
#  'AM-4030',
#  'AM-411',
#  'AM-4113',
#  'AM-630',
#  'AM-6527',
#  'AM-6545',
#  'AM-679 (cannabinoid)',
#  'AM-694',
#  'AM-855',
#  'AM-883',
#  'AM-905',
#  'AM-906',
#  'AM-919',
#  'AM-926',
#  'AM-938',
#  'AM251',
#  'AM281',
#  'AM404',
#  'AMB-CHMINACA',
#  'AMB-FUBINACA',
#  'AMG-1',
#  'AMG-3',
#  'AMG-36',
#  'AMG-41',
#  'APICA (synthetic cannabinoid drug)',
#  'APINACA',
#  'APP-FUBINACA',
#  'AZ-11713908',
#  'Abnormal cannabidiol',
#  'Acid Tests',
#  'Acid Western',
#  'Acid house',
#  'Acid jazz',
#  'Acid rock',
#  'Acid techno',
#  'Acid trance',
#  'Active ingredient',
#  'Addiction',
#  'Aeruginascin',
#  'Agonist',
#  'Ajulemic acid',
#  'Albert Hofmann',
#  'Aleph (psychedelic)',
#  'Alexander Shulgin',
#  'Algorithmic art',
#  'Alkoxy',
#  'Alkylated',
#  'Allosteric modulator',
#  'Allylescaline',
#  'Alpha,N,O-TMS',
#  'Alpha,N-DMT',
#  'Alpha-Trimethyltryptamine',
#  'Alpha-ethyltryptamine',
#  'Alpha-methyltryptamine',
#  'Amanita muscaria',
#  'Amphetamine',
#  'Arachidonoyl serotonin',
#  "Arachidonyl-2'-chloroethylamide",
#  'Arachidonylcyclopropylamide',
#  'Argyreia nervosa',
#  'Ariadne (psychedelic)',
#  'Arvanil',
#  'Asymbescaline',
#  'Atropine',
#  'Ayahuasca',
#  'BAY 38-7271',
#  'BAY 59-3074',
#  'BIM-018',
#  'BML-190',
#  'BOB (psychedelic)',
#  'BOD (psychedelic)',
#  'BOHD (psychedelic)',
#  'BOH (psychedelic)',
#  'BOM (psychedelic)',
#  'BU-LAD',
#  'Bad trip',
#  'Baeocystin',
#  'Beatrice (psychedelic)',
#  'Benzodioxolylbutanamine',
#  'Benzofuran',
#  'Benzoxazine',
#  'Beta-D',
#  'Beta-carboline',
#  'Biochanin A',
#  'Bis-TOM',
#  'Bromo-DragonFLY',
#  'Bufotenin',
#  'Buscaline',
#  'Butylone',
#  'CAY-10401',
#  'CAY-10429',
#  'CAY-10508',
#  'CB-13',
#  'CB-25',
#  'CB-52',
#  'CB-86',
#  'CBS-0550',
#  'CP-132,484',
#  'CP 47,497',
#  'CP 55,244',
#  'CP 55,940',
#  'CUMYL-5F-PICA',
#  'CUMYL-BICA',
#  'CUMYL-PICA',
#  'CUMYL-PINACA',
#  'CUMYL-THPINACA',
#  'CYP-LAD',
#  'Canbisol',
#  'Cannabicyclohexanol',
#  'Cannabidiol',
#  'Cannabinoid receptor type 1',
#  'Cannabinol',
#  'Cannabipiperidiethanone',
#  'Cannabis (Drug)',
#  'Cannabis (drug)',
#  'Chemical decomposition',
#  'Chillwave',
#  'Counterculture',
#  'Cryogenine',
#  'Cyberdelic',
#  'Cyclopropylmescaline',
#  'DMBMPP',
#  'DMCPA',
#  'DME (psychedelic)',
#  'DMMDA',
#  'DMMDA-2',
#  'DOAM',
#  'DOBU',
#  'DOEF',
#  'DOTFM',
#  'DOx',
#  'Deacetylation',
#  'Demethylation',
#  'Dephosphorylation',
#  'Dexanabinol',
#  'DiFMDA',
#  'Diallyllysergamide',
#  'Diallyltryptamine',
#  'Dibutyltryptamine',
#  'Diethyltryptamine',
#  'Diffraction',
#  'Diisopropyltryptamine',
#  'Dimemebfe',
#  'Dimethoxyamphetamine',
#  'Dimethylheptylpyran',
#  'Dimethyllysergamide',
#  'Dimethyltryptamine',
#  'Dipropyltryptamine',
#  'Dissociative drug',
#  'Doi (identifier)',
#  'Drinabant',
#  'Dronabinol',
#  'Drug culture',
#  'Drug liberalization',
#  'Drug policy of the Netherlands',
#  'EAM-2201',
#  'EDMA',
#  'EEE (psychedelic)',
#  'EEM (psychedelic)',
#  'EIDA',
#  'EMB-FUBINACA',
#  'EME (psychedelic)',
#  'EMM (psychedelic)',
#  'ETH-LAD',
#  'Echinopsis pachanoi',
#  'Efavirenz',
#  'Ego death',
#  'Elemicin',
#  'Entheogen',
#  'Ergolines',
#  'Ergometrine',
#  'Ergot',
#  'Escaline',
#  'Ethocybin',
#  'Ethyl-J',
#  'Ethyl-K',
#  'Ethylisopropyltryptamine',
#  'Ethylone',
#  'Ethyltrifluoromethylaminoindane',
#  'Eutylone',
#  'F-22 (psychedelic)',
#  'F-2 (psychedelic)',
#  'FAB-144',
#  'FDU-NNE1',
#  'FDU-PB-22',
#  'FLEA (psychedelic)',
#  'FUB-144',
#  'FUB-APINACA',
#  'FUB-JWH-018',
#  'FUB-PB-22',
#  'FUBIMINA',
#  'Fractal art',
#  'GW-405,833',
#  'GW-842,166X',
#  'Ganesha (psychedelic)',
#  'Genistein',
#  'HOT-17',
#  'HOT-2',
#  'HOT-7',
#  'HU-210',
#  'HU-243',
#  'HU-308',
#  'HU-320',
#  'HU-331',
#  'HU-336',
#  'HU-345',
#  'HU-910',
#  'Harmala alkaloid',
#  'Harmaline',
#  'Heimia',
#  'Hemopressin',
#  'History of lysergic acid diethylamide',
#  'Hydrolyzation',
#  'Hyoscine hydrobromide',
#  'Hyoscyamine',
#  'Hypnagogic pop',
#  'IDFP',
#  'IDNNA',
#  'ISBN (identifier)',
#  'ISSN (identifier)',
#  'Ibipinabant',
#  'Ibogaine',
#  'Ibotenic acid',
#  'Indanylaminopropane',
#  'Indole',
#  'Indoles',
#  'Inocybe aeruginascens',
#  'Invertebrate',
#  'Iris (psychedelic)',
#  'Isomescaline',
#  'Isoproscaline',
#  'JNJ 1661010',
#  'JTE-907',
#  'JTE 7-31',
#  'JWH-007',
#  'JWH-015',
#  'JWH-018',
#  'JWH-019',
#  'JWH-030',
#  'JWH-051',
#  'JWH-073',
#  'JWH-081',
#  'JWH-098',
#  'JWH-116',
#  'JWH-122',
#  'JWH-133',
#  'JWH-139',
#  'JWH-147',
#  'JWH-149',
#  'JWH-161',
#  'JWH-164',
#  'JWH-167',
#  'JWH-175',
#  'JWH-176',
#  'JWH-182',
#  'JWH-184',
#  'JWH-185',
#  'JWH-192',
#  'JWH-193',
#  'JWH-194',
#  'JWH-195',
#  'JWH-196',
#  'JWH-197',
#  'JWH-198',
#  'JWH-199',
#  'JWH-200',
#  'JWH-203',
#  'JWH-210',
#  'JWH-229',
#  'JWH-249',
#  'JWH-250',
#  'JWH-251',
#  'JWH-302',
#  'JWH-307',
#  'JWH-359',
#  'JWH-369',
#  'JWH-370',
#  'JWH-398',
#  'JWH-424',
#  'JZL184',
#  'JZL195',
#  'Jimscaline',
#  'KM-233',
#  'Kaempferol',
#  'L-759,633',
#  'L-759,656',
#  'LASSBio-881',
#  'LBP-1 (drug)',
#  'LH-21',
#  'LSD-Pip',
#  'LSD art',
#  'LSM-775',
#  'LY-2183240',
#  'LY-320,135',
#  'Leelamine',
#  'Legal status of Salvia divinorum',
#  'Legal status of psilocybin mushrooms',
#  'Legality of cannabis',
#  'Levonantradol',
#  'Liquid light show',
#  'List of designer drugs',
#  'List of entheogens',
#  'List of psilocybin mushrooms',
#  'Lophophine',
#  'Lysergamides',
#  'Lysergic acid 2,4-dimethylazetidide',
#  'Lysergic acid 2-butyl amide',
#  'Lysergic acid 3-pentyl amide',
#  'Lysergic acid amide',
#  'Lysergic acid ethylamide',
#  'Lysergic acid hydroxyethylamide',
#  'Lysergic acid methyl ester',
#  'MAM-2201',
#  'MAOI',
#  'MBDB',
#  'MDA-19',
#  'MDA-7',
#  'MDA-77',
#  'MDAI',
#  'MDAL',
#  'MDAT',
#  'MDBU',
#  'MDBZ',
#  'MDCPM',
#  'MDDM',
#  'MDHOET',
#  'MDIP',
#  'MDMA',
#  'MDMAI',
#  'MDMAT',
#  'MDMB-CHMICA',
#  'MDMB-CHMINACA',
#  'MDMB-FUBINACA',
#  'MDMEO',
#  'MDMEOET',
#  'MDOH',
#  'MDPH',
#  'MDPL',
#  'MDPR',
#  'MDxx',
#  'MEDA',
#  'MEE (psychedelic)',
#  'MEM (psychedelic)',
#  'MEPIRAPIM',
#  'MJ-15',
#  'MK-9470',
#  'MMAI',
#  'MMB-2201',
#  'MMDA-2',
#  'MMDA (psychedelic)',
#  'MME (psychedelic)',
#  'MN-18',
#  'MPM (psychedelic)',
#  'Macromerine',
#  'Madam-6',
#  'Madchester',
#  'Menabitan',
#  'Meta-DOB',
#  'Meta-DOT',
#  'Metabolite',
#  'Metaescaline',
#  'Metaproscaline',
#  'Methallylescaline',
#  'Methanandamide',
#  'Methyl-DMA',
#  'Methyl-DOB',
#  'Methylbenzodioxolylbutanamine',
#  'Methylbenzodioxolylpentanamine',
#  'Methylbutyltryptamine',
#  'Methylenedioxyethylamphetamine',
#  'Methylenedioxymethylphentermine',
#  'Methylergometrine',
#  'Methylethyltryptamine',
#  'Methylisopropyllysergamide',
#  'Methylisopropyltryptamine',
#  'Methylone',
#  'Methylpropyltryptamine',
#  'Methysergide',
#  'Morning glory',
#  'Muscimol',
#  'Myristicin',
#  'N-(S)-Fenchyl-1-(2-morpholinoethyl)-7-methoxyindole-3-carboxamide',
#  'N-Ethyltryptamine',
#  'N-Methyltryptamine',
#  'N-Pyrrolidyllysergamide',
#  'N1-Methyl-lysergic acid diethylamide',
#  'NBOMe-mescaline',
#  'NESS-0327',
#  'NESS-040C5',
#  'NIDA-41020',
#  'NM-2201',
#  'NMP-7',
#  'NNE1',
#  'Nabazenil',
#  'Nabilone',
#  'Nabitan',
#  'Naboctate',
#  'Naphthylaminopropane',
#  'Neo-psychedelia',
#  'Nonabine',
#  'Norfenfluramine',
#  'Nutmeg',
#  'O-1057',
#  'O-1125',
#  'O-1184',
#  'O-1191',
#  'O-1238',
#  'O-1248',
#  'O-1269',
#  'O-1270',
#  'O-1376',
#  'O-1399',
#  'O-1422',
#  'O-1601',
#  'O-1602',
#  'O-1624',
#  'O-1656',
#  'O-1657',
#  'O-1660',
#  'O-1812',
#  'O-1860',
#  'O-1861',
#  'O-1871',
#  'O-1918',
#  'O-2048',
#  'O-2050',
#  'O-2093',
#  'O-2113',
#  'O-2220',
#  'O-224',
#  'O-2365',
#  'O-2372',
#  'O-2373',
#  'O-2383',
#  'O-2426',
#  'O-2484',
#  'O-2545',
#  'O-2654',
#  'O-2694',
#  'O-2715',
#  'O-2716',
#  'O-3223',
#  'O-3226',
#  'O-4310',
#  'O-581',
#  'O-585',
#  'O-606',
#  'O-689',
#  'O-774',
#  'O-806',
#  'O-823',
#  'O-889',
#  'O-Acetylpsilocin',
#  'OCLC (identifier)',
#  'Oleoylethanolamide',
#  'Olvanil',
#  'Oral administration',
#  'Org 27569',
#  'Org 27759',
#  'Org 28312',
#  'Org 28611',
#  'Org 29647',
#  'Ortho-DOT',
#  'Otenabant',
#  'Owsley Stanley',
#  'P-Funk',
#  'PARGY-LAD',
#  'PF-03550096',
#  'PF-04457845',
#  'PF-3845',
#  'PF-514273',
#  'PF-622',
#  'PF-750',
#  'PFPP',
#  'PHOP',
#  'PMC (identifier)',
#  'PMID (identifier)',
#  'PRO-LAD',
#  'PSB-SB-1202',
#  'PSB-SB-487',
#  'PTI-1',
#  'PTI-2',
#  'PX-1',
#  'PX-2',
#  'PX-3',
#  'Paisley (design)',
#  'Palmitoylethanolamide',
#  'Para-Chloroamphetamine',
#  'Para-Iodoamphetamine',
#  'Para-Methoxyamphetamine',
#  'Parahexyl',
#  'Paramethoxymethamphetamine',
#  'Pentylone',
#  'Peyote',
#  'Peyote song',
#  'Pharmacodynamic',
#  'Phenescaline',
#  'Phenethylamine',
#  'Philosophy of psychedelics',
#  'Phosphene',
#  'Phytocannabinoids',
#  'PiHKAL',
#  'PipISB',
#  'Piperazine',
#  'Pirnabine',
#  'Pravadoline',
#  'Pregnenolone',
#  'Prodrug',
#  'Prohibition of drugs',
#  'Propylisopropyltryptamine',
#  'Propynyl (psychedelic)',
#  'Proscaline',
#  'Psi-DOM',
#  'Psilocin',
#  'Psilocybe',
#  'Psilocybin',
#  'Psychedelia',
#  'Psychedelic art',
#  'Psychedelic drug',
#  'Psychedelic era',
#  'Psychedelic experience',
#  'Psychedelic film',
#  'Psychedelic folk',
#  'Psychedelic literature',
#  'Psychedelic microdosing',
#  'Psychedelic music',
#  'Psychedelic plants',
#  'Psychedelic pop',
#  'Psychedelic rock',
#  'Psychedelic soul',
#  'Psychedelic therapy',
#  'Psychedelic trance',
#  'Psychedelics and ecology',
#  'Psychoactive cactus',
#  'Psychoactive toads',
#  'Psychonautics',
#  'Pyr-T',
#  'QUCHIC',
#  'QUPIC',
#  'RCS-4',
#  'RCS-8',
#  'RTI-371',
#  'RU-28306',
#  'Rave',
#  'Recreational drug use',
#  'Rimonabant',
#  'Rosonabant',
#  'S-444,823',
#  'SDB-006',
#  'SER-601',
#  'SPA-229',
#  'SR-144,528',
#  'STS-135 (drug)',
#  'Salvia divinorum',
#  'Salvinorin A',
#  'Salvinorin B ethoxymethyl ether',
#  'Salvinorin B methoxymethyl ether',
#  'San Pedro cactus',
#  'Serotonergic psychedelic',
#  'Serotonergic psychedelics',
#  'Serotonin receptor agonist',
#  'Serotonin releasing agent',
#  'Smart shop',
#  'Smenospongia aurea',
#  'Smenospongia echina',
#  'Solanaceae',
#  'Space rock',
#  'Stoner film',
#  'Stoner rock',
#  'Summer of Love',
#  'Surinabant',
#  'Surrealism',
#  'Symbescaline',
#  'Synthetic cannabis',
#  'TFMFly',
#  'TFMPP',
#  'THC-O-acetate',
#  'THC-O-phosphate',
#  'THJ-018',
#  'THJ-2201',
#  'TIM (psychedelics)',
#  'TM-38837',
#  'TME (psychedelics)',
#  'TOET (psychedelic)',
#  'TOMSO',
#  'TOM (psychedelic)',
#  'Tabernanthe iboga',
#  'Taranabant',
#  'Tedalinab',
#  'Tetrahydrocannabinol',
#  'Tetrahydrocannabivarin',
#  'Tetralinylaminopropane',
#  'Tetramethoxyamphetamine',
#  'Thiobuscaline',
#  'Thioproscaline',
#  'Thiosymbescaline',
#  'Thiotrisescaline',
#  'TiHKAL',
#  'Timothy Leary',
#  'Tinabinol',
#  'Trace amine',
#  'Trifluoromethylaminoindane',
#  'Trimethoxyamphetamine',
#  'Trimethyltryptamine',
#  'Trip hop',
#  'Trip sitter',
#  'Trisescaline',
#  'Tryptamine',
#  'UR-144',
#  'URB-447',
#  'URB447',
#  'URB597',
#  'URB602',
#  'URB754',
#  'VCHSR',
#  'VDM-11',
#  'VSN-16',
#  'Verongula rigida',
#  'Voacangine',
#  'WIN 54,461',
#  'WIN 55,212-2',
#  'WIN 56,098',
#  'William Leonard Pickard',
#  'XLR-11 (drug)',
#  'Yangonin',
#  'Βk-2C-B',
#  'Κ-opioid receptor',
#  'Ψ-2C-T-4',
#  '((pF)Phe4)Nociceptin(1-13)NH2',
#  '(Arg14,Lys15)Nociceptin',
#  '(D-Ser2, Leu5, Thr6)-Enkephalin',
#  '(Nphe1)Nociceptin(1-13)NH2',
#  '(Phe1Ψ(CH2-NH)Gly2)Nociceptin(1-13)NH2',
#  '1-(4-Nitrophenylethyl)piperidylidene-2-(4-chlorophenyl)sulfonamide',
#  '1-Bromocodeine',
#  '1-Chlorocodeine',
#  '1-Iodomorphine',
#  '1-Nitroaknadinine',
#  '1-Nitrocodeine',
#  '14-Cinnamoyloxycodeinone',
#  '14-Ethoxymetopon',
#  '14-Hydroxydihydrocodeine',
#  '14-Hydroxymorphine',
#  '14-Methoxymetopon',
#  '14-Phenylpropoxymetopon',
#  '14-episinomenine',
#  '18,19-Dehydrobuprenorphine',
#  '18-Methoxycoronaridine',
#  '2,4-Dinitrophenylmorphine',
#  '3,14-Diacetyloxymorphone',
#  '3,6-Dibutanoylmorphine',
#  '3-(3-Methoxyphenyl)-3-ethoxycarbonyltropane',
#  '3-(dimethylamino)-2,2-dimethyl-1-phenylpropan-1-one',
#  '3-Acetyloxymorphone',
#  '3-Allylfentanyl',
#  '3-HO-PCP',
#  '3-Hydroxymorphinan',
#  '3-Methylfentanyl',
#  '3-Methylthiofentanyl',
#  '3-Monoacetylmorphine',
#  '3CS-nalmefene',
#  "4',7-Dihydroxyflavone",
#  '4-Caffeoyl-1,5-quinide',
#  '4-Chlorophenylpyridomorphinan',
#  '4-Fluoromeperidine',
#  '4-Fluoropethidine',
#  '4-Phenylfentanyl',
#  '4-Phenylpiperidine',
#  '4-chlorophenylpyridomorphinan',
#  '4′-Hydroxyflavanone',
#  "5'-Acetamidinoethylnaltrindole",
#  "5'-Guanidinonaltrindole",
#  '5,6-Dihydronorsalutaridine',
#  '5,9 alpha-diethyl-2-hydroxybenzomorphan',
#  "6'-Guanidinonaltrindole",
#  '6-Acetyldihydromorphine',
#  '6-Acetyldihydromorphine hydrochloride',
#  '6-Keto Nalbuphine',
#  '6-Methyldihydromorphine',
#  '6-Methylenedihydrodesoxymorphine',
#  '6-Monoacetylcodeine',
#  '6-Monoacetylmorphine',
#  '6-Nicotinoyldihydromorphine',
#  '6-nicotinoyldihydromorphine',
#  '6β-Naltrexol',
#  '6β-Naltrexol-d4',
#  '7-Acetoxymitragynine',
#  '7-Benzylidenenaltrexone',
#  '7-Hydroxymitragynine',
#  '7-PET',
#  '7-Spiroindanyloxymorphone',
#  '8,14-Dihydroxydihydromorphinone',
#  '8-Carboxamidocyclazocine',
#  'AD-1211',
#  'ADL-5747',
#  'ADL-5859',
#  'AH-7921',
#  'AM-251 (drug)',
#  'AR-M100390',
#  'AT-076',
#  'AZ-MTAB',
#  'AZD-2327',
#  'AZD2327',
#  'Ac-RYYRIK-NH2',
#  'Ac-RYYRWK-NH2',
#  'Acetorphine',
#  'Acetoxyketobemidone',
#  'Acetylcodone',
#  'Acetyldihydrocodeine',
#  'Acetylfentanyl',
#  'Acetylmethadol',
#  'Acetylmorphone',
#  'Acetylpropionylmorphine',
#  'Acrylfentanyl',
#  'Adrenorphin',
#  'Aknadinine',
#  'Akuammicine',
#  'Akuammidine',
#  'Akuammine',
#  'Akuuamicine',
#  'Alazocine',
#  'Alfentanil',
#  'Alimadol',
#  'Alletorphine',
#  'Allomatrine',
#  'Allylnorpethidine',
#  'Allylprodine',
#  'Alpha-Gliadin',
#  'Alpha-Narcotine',
#  'Alpha-Santolol',
#  'Alpha-endorphin',
#  'Alphaacetylmethadol',
#  'Alphamethadol',
#  'Alphamethylacetylfentanyl',
#  'Alphamethylfentanyl',
#  'Alphamethylthiofentanyl',
#  'Alvimopan',
#  'Amastatin',
#  'Amentoflavone',
#  'Amidogen',
#  'Amidorphin',
#  'Amine',
#  'Amitriptyline',
#  'Amoxapine',
#  'Anazocine',
#  'Anileridine',
#  ...]

# %%
text_corpus['title'].to_csv('data/linkListV0.2.csv', index=False)
